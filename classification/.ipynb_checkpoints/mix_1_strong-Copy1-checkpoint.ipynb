# %%
import torch
from torch import nn
from torchvision import transforms
from torchvision import models
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFilter
from PIL import ImageOps
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
from copy import copy
from copy import deepcopy
import sys
import os
import pandas as pd
import numpy as np
import random
from pathlib import Path

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True' # dead kernel for matplotlib

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
metadata = pd.read_csv('../doby_meta.csv')
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7064 entries, 0 to 7063
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      7064 non-null   int64
#  1   study_id        7064 non-null   int64
#  2   dicom_id        7064 non-null   object
#  3   DicomPath       7064 non-null   object
#  4   edema_severity  7064 non-null   int64
#  5   normal          7064 non-null   int64
#  6   CHF             7064 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 338.2+ KB

# %%
metadata = metadata[metadata['subject_id'] < 16000000]
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4198 entries, 0 to 4197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      4198 non-null   int64
#  1   study_id        4198 non-null   int64
#  2   dicom_id        4198 non-null   object
#  3   DicomPath       4198 non-null   object
#  4   edema_severity  4198 non-null   int64
#  5   normal          4198 non-null   int64
#  6   CHF             4198 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 233.7+ KB

# %%
SEG_BASE_PATH = '../chest-x-ray-dataset-with-lung-segmentation-1.0.0/chest-x-ray-dataset-with-lung-segmentation-1.0.0'
ORIG_BASE_PATH = '../physionet.org/files/mimic-cxr-jpg/2.0.0'

# %%
class Resize(object):
    def __init__(self, size):
        self.size = size

    def __call__(self, x_seg, x_orig):
        return x_seg, x_orig.resize((self.size, self.size))

class MixImage(object):
    def __call__(self, fore, back):
        back.paste(fore, (0, 0), fore)
        return back

MIX_TRANSFORMS = transforms.Compose([
    transforms.ToTensor()
])

# %%
class Dataset(Dataset):
    def __init__(self, metadata, seg_base_path, orig_base_path, transform=None):
        self.metadata = metadata
        self.seg_base_path = Path(seg_base_path)
        self.orig_base_path = Path(orig_base_path)
        self.transform = transform

    def __getitem__(self, idx):
        x_path = self.metadata.loc[idx, 'DicomPath']
        x_seg_path = self.seg_base_path / Path(x_path)
        x_orig_path = self.orig_base_path / Path(x_path)
        
        x_seg = Image.open(x_seg_path).convert('L') # convert를 하지 않으면, ToTensor를 할 때, 3x224x224로 바꾼다.
        x_orig = Image.open(x_orig_path).convert('L').resize(x_seg.size)

        '''
        plt.subplot(2, 2, 1)
        plt.imshow(x_orig, cmap='gray')
        plt.axis('off')
                    
        plt.subplot(2, 2, 2)
        plt.imshow(x_seg, cmap='gray')
        plt.axis('off')
        '''
        
        x_orig = x_orig.filter(ImageFilter.GaussianBlur(1.5)) # radius

        '''
        plt.subplot(2, 2, 3)
        plt.imshow(x_orig, cmap='gray')
        plt.axis('off')
        '''

        # 0.2에서 0.3로
        # second image의 가중치를 더 높게
        x_mix = Image.blend(x_orig, x_seg, 0.3) 

        # Histogram Equalization
        x_mix = ImageOps.equalize(x_mix)

        '''
        plt.subplot(2, 2, 4)
        plt.imshow(x_mix, cmap='gray')
        plt.axis('off')
        plt.show()
        '''
        
        y = self.metadata.loc[idx, 'normal']

        if self.transform:
            x = self.transform(x_mix)

        return x, y

    def __len__(self):
        return self.metadata['normal'].count()

# %%
mix_ds = Dataset(metadata, SEG_BASE_PATH, ORIG_BASE_PATH, transform=MIX_TRANSFORMS)

# %%
from torchvision.transforms.functional import to_pil_image

x, y = mix_ds[201]
plt.title(y)
plt.imshow(to_pil_image(x), cmap='gray')
plt.axis('off')
plt.show()

# %%
ds_size = len(mix_ds)
train_size = int(ds_size * 0.8)
test_size = ds_size - train_size
mix_train, mix_test = random_split(mix_ds, [train_size, test_size], generator=torch.manual_seed(42))

# %%
print(len(mix_train), len(mix_test))
# Out:
# 3358 840

# %%
mix_train = copy(mix_train)

TRAIN_TRANSFORM = transforms.Compose([
    transforms.ToTensor(),
    # rotation degree = -10, 10
    # translate -img_width * a < dx < img_width * a
        # -11.2 < dx < 11.2, y도 b로 마찬가지, tuple 형태로
    transforms.RandomAffine(degrees=10, translate=(0.05, 0.05))
])

mix_train.dataset.transform = TRAIN_TRANSFORM

# %%
mix_train_dl = DataLoader(mix_train, batch_size=16, shuffle=True)
mix_test_dl = DataLoader(mix_test, batch_size=8, shuffle=True)

# %%
class customDenseNet(nn.Module):
    def __init__(self):
        super(customDenseNet, self).__init__()
        self.model = models.densenet121(weights='IMAGENET1K_V1')
        self.model.features.conv0 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.linear = nn.Linear(1000, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.model(x)
        x = self.linear(x)
        x = self.sigmoid(x)

        return x

# %%
mix_net = customDenseNet()
mix_net.to(device)
# Out:
# customDenseNet(
#   (model): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition1): _Transition(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock2): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition2): _Transition(
#         (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock3): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition3): _Transition(
#         (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock4): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (classifier): Linear(in_features=1024, out_features=1000, bias=True)
#   )
#   (linear): Linear(in_features=1000, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
optimizer = torch.optim.Adam(mix_net.parameters(), lr=0.0001)
schedular = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
weights = (metadata['normal'] == 0).sum() / (metadata['normal'] == 1).sum()
loss_fn = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([weights])).to(device)

# %%
def train(model, data_loader, optimizer, epoch):
    model.train()
    running_loss = 0
    running_acc = 0
    n_data = 0

    for batch_idx, (batch, target) in enumerate(data_loader, start=1):
        batch, target = batch.to(device), target.to(device)

        optimizer.zero_grad()

        output = model(batch)
        # print(output.shape, target.shape)
        target_ = target
        target = target.unsqueeze(dim=-1).float()

        loss = loss_fn(output, target)
        running_loss += loss.item()

        predicted = (output >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)
        correct = (predicted == target).sum().item()
        running_acc += correct

        loss.backward()
        optimizer.step()

        n_data += len(batch)
        print(f'\rTrain Epoch: {epoch} [{n_data}/{len(data_loader.dataset)} ({100 * batch_idx / len(data_loader):.2f}%)]  Accuracy: {100*running_acc/n_data:.2f}%  Loss: {running_loss/batch_idx:.4f}', end='')

# %%
TP, FP, TN, FN = 0, 0, 0, 0

predicted = torch.Tensor([[1], [0], [0], [1]]).float()
target = torch.Tensor([[0], [1], [0], [1]]).float()

TP += ((predicted == target) & (target == 1)).sum().item()
FP += ((predicted != target) & (target == 0)).sum().item()
TN += ((predicted == target) & (target == 0)).sum().item()
FN += ((predicted != target) & (target == 1)).sum().item()

print(TP, FP, TN, FN)
# Out:
# 1 1 1 1

# %%
def test(model, data_loader):
    model.eval()
    test_acc = 0
    test_loss = 0
    n_data = 0
    TP, FP, TN, FN = 0, 0, 0, 0
    with torch.no_grad():
        for batch, target in data_loader:
            batch, target = batch.to(device), target.to(device)

            output = model(batch)
            target = target.unsqueeze(dim=-1).float()

            loss = loss_fn(output, target)
            test_loss += loss.item()

            predicted = (output >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)
            correct = (predicted == target).sum().item()
            test_acc += correct

            TP += ((predicted == target) & (target == 1)).sum().item()
            FP += ((predicted != target) & (target == 0)).sum().item()
            TN += ((predicted == target) & (target == 0)).sum().item()
            FN += ((predicted != target) & (target == 1)).sum().item()
            
            n_data += len(batch)
            print(f'\rTest set: [{100*n_data/len(data_loader.dataset):.2f}%]', end='')
    
    test_acc = 100 * test_acc / len(data_loader.dataset)
    test_loss = test_loss / len(data_loader)
    
    print(f'\rTest set: Accuracy: {test_acc:.2f}%  Loss: {test_loss:.4f}')

    return test_acc, test_loss, TP, FP, TN, FN

# %%
def getMetric(TP, FP, TN, FN):
    # base case: divide by zero
    TP = 0.1 if TP == 0 else TP
    FP = 0.1 if FP == 0 else FP
    TN = 0.1 if TN == 0 else TN
    FN = 0.1 if FN == 0 else FN
    
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    f1_score = 2*precision*recall/(precision+recall)
    return sensitivity, specificity, f1_score

# %%
accs = []
losses = []
best_acc = 0
best_f1 = 0

best_acc_model = None
best_acc_model_state = None
best_f1_model = None
best_f1_model_state = None

# %%
for epoch in range(1, 100+1):
    train(mix_net, mix_train_dl, optimizer, epoch)
    
    print()
    
    acc, loss, tp, fp, tn, fn = test(mix_net, mix_test_dl)
    sensitivity, specificity, f1_score = getMetric(tp, fp, tn, fn)
    print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')
    print(f'Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, F1-Score: {f1_score:.4f}')

    if acc > best_acc:
        best_acc = acc
        best_acc_model = deepcopy(mix_net)
        best_acc_model_state = deepcopy(mix_net.state_dict())

    if f1_score > best_f1:
        best_f1 = f1_score
        best_f1_model = deepcopy(mix_net)
        best_f1_model_state = deepcopy(mix_net.state_dict())
        
    schedular.step(loss)
    accs.append(acc)
    losses.append(loss)

    print('================================================================')
# Out:
# Train Epoch: 1 [3358/3358 (100.00%)]  Accuracy: 64.53%  Loss: 0.7484
# Test set: Accuracy: 62.50%  Loss: 0.7491
# TP: 237, FP: 51, TN: 288, FN: 264
# Sensitivity: 0.4731, Specificity: 0.8496, F1-Score: 0.6008
# ================================================================
# Train Epoch: 2 [3358/3358 (100.00%)]  Accuracy: 67.27%  Loss: 0.7330
# Test set: Accuracy: 67.62%  Loss: 0.7275
# TP: 357, FP: 128, TN: 211, FN: 144
# Sensitivity: 0.7126, Specificity: 0.6224, F1-Score: 0.7241
# ================================================================
# Train Epoch: 3 [3358/3358 (100.00%)]  Accuracy: 69.36%  Loss: 0.7244
# Test set: Accuracy: 67.86%  Loss: 0.7242
# TP: 299, FP: 68, TN: 271, FN: 202
# Sensitivity: 0.5968, Specificity: 0.7994, F1-Score: 0.6889
# ================================================================
# Train Epoch: 4 [3358/3358 (100.00%)]  Accuracy: 70.82%  Loss: 0.7165
# Test set: Accuracy: 70.71%  Loss: 0.7102
# TP: 397, FP: 142, TN: 197, FN: 104
# Sensitivity: 0.7924, Specificity: 0.5811, F1-Score: 0.7635
# ================================================================
# Train Epoch: 5 [3358/3358 (100.00%)]  Accuracy: 70.73%  Loss: 0.7169
# Test set: Accuracy: 72.98%  Loss: 0.7017
# TP: 430, FP: 156, TN: 183, FN: 71
# Sensitivity: 0.8583, Specificity: 0.5398, F1-Score: 0.7912
# ================================================================
# Train Epoch: 6 [3358/3358 (100.00%)]  Accuracy: 70.76%  Loss: 0.7149
# Test set: Accuracy: 71.90%  Loss: 0.7094
# TP: 416, FP: 151, TN: 188, FN: 85
# Sensitivity: 0.8303, Specificity: 0.5546, F1-Score: 0.7790
# ================================================================
# Train Epoch: 7 [3358/3358 (100.00%)]  Accuracy: 71.29%  Loss: 0.7139
# Test set: Accuracy: 65.00%  Loss: 0.7403
# TP: 311, FP: 104, TN: 235, FN: 190
# Sensitivity: 0.6208, Specificity: 0.6932, F1-Score: 0.6790
# ================================================================
# Train Epoch: 8 [3358/3358 (100.00%)]  Accuracy: 69.51%  Loss: 0.7211
# Test set: Accuracy: 72.02%  Loss: 0.7088
# TP: 415, FP: 149, TN: 190, FN: 86
# Sensitivity: 0.8283, Specificity: 0.5605, F1-Score: 0.7793
# ================================================================
# Train Epoch: 9 [3358/3358 (100.00%)]  Accuracy: 72.28%  Loss: 0.7083
# Test set: Accuracy: 67.62%  Loss: 0.7250
# TP: 308, FP: 79, TN: 260, FN: 193
# Sensitivity: 0.6148, Specificity: 0.7670, F1-Score: 0.6937
# ================================================================
# Train Epoch: 10 [3358/3358 (100.00%)]  Accuracy: 71.59%  Loss: 0.7111
# Test set: Accuracy: 68.10%  Loss: 0.7248
# TP: 329, FP: 96, TN: 243, FN: 172
# Sensitivity: 0.6567, Specificity: 0.7168, F1-Score: 0.7106
# ================================================================
# Train Epoch: 11 [3358/3358 (100.00%)]  Accuracy: 72.25%  Loss: 0.7080
# Test set: Accuracy: 73.69%  Loss: 0.6981
# TP: 383, FP: 103, TN: 236, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6962, F1-Score: 0.7761
# ================================================================
# Train Epoch: 12 [3358/3358 (100.00%)]  Accuracy: 72.01%  Loss: 0.7081
# Test set: Accuracy: 71.07%  Loss: 0.7157
# TP: 435, FP: 177, TN: 162, FN: 66
# Sensitivity: 0.8683, Specificity: 0.4779, F1-Score: 0.7817
# ================================================================
# Train Epoch: 13 [3358/3358 (100.00%)]  Accuracy: 72.45%  Loss: 0.7074
# Test set: Accuracy: 71.19%  Loss: 0.7118
# TP: 405, FP: 146, TN: 193, FN: 96
# Sensitivity: 0.8084, Specificity: 0.5693, F1-Score: 0.7700
# ================================================================
# Train Epoch: 14 [3358/3358 (100.00%)]  Accuracy: 73.08%  Loss: 0.7032
# Test set: Accuracy: 72.50%  Loss: 0.7050
# TP: 430, FP: 160, TN: 179, FN: 71
# Sensitivity: 0.8583, Specificity: 0.5280, F1-Score: 0.7883
# ================================================================
# Train Epoch: 15 [3358/3358 (100.00%)]  Accuracy: 72.42%  Loss: 0.7072
# Test set: Accuracy: 72.86%  Loss: 0.7057
# TP: 454, FP: 181, TN: 158, FN: 47
# Sensitivity: 0.9062, Specificity: 0.4661, F1-Score: 0.7993
# ================================================================
# Train Epoch: 16 [3358/3358 (100.00%)]  Accuracy: 71.74%  Loss: 0.7104
# Test set: Accuracy: 65.36%  Loss: 0.7386
# TP: 318, FP: 108, TN: 231, FN: 183
# Sensitivity: 0.6347, Specificity: 0.6814, F1-Score: 0.6861
# ================================================================
# Train Epoch: 17 [3358/3358 (100.00%)]  Accuracy: 73.20%  Loss: 0.7008
# Test set: Accuracy: 67.50%  Loss: 0.7221
# TP: 289, FP: 61, TN: 278, FN: 212
# Sensitivity: 0.5768, Specificity: 0.8201, F1-Score: 0.6792
# Epoch 00017: reducing learning rate of group 0 to 1.0000e-05.
# ================================================================
# Train Epoch: 18 [3358/3358 (100.00%)]  Accuracy: 74.57%  Loss: 0.6912
# Test set: Accuracy: 74.64%  Loss: 0.6928
# TP: 396, FP: 108, TN: 231, FN: 105
# Sensitivity: 0.7904, Specificity: 0.6814, F1-Score: 0.7881
# ================================================================
# Train Epoch: 19 [3358/3358 (100.00%)]  Accuracy: 77.10%  Loss: 0.6795
# Test set: Accuracy: 74.40%  Loss: 0.6894
# TP: 390, FP: 104, TN: 235, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6932, F1-Score: 0.7839
# ================================================================
# Train Epoch: 20 [3358/3358 (100.00%)]  Accuracy: 77.55%  Loss: 0.6763
# Test set: Accuracy: 73.57%  Loss: 0.6973
# TP: 394, FP: 115, TN: 224, FN: 107
# Sensitivity: 0.7864, Specificity: 0.6608, F1-Score: 0.7802
# ================================================================
# Train Epoch: 21 [3358/3358 (100.00%)]  Accuracy: 78.14%  Loss: 0.6729
# Test set: Accuracy: 74.17%  Loss: 0.6915
# TP: 391, FP: 107, TN: 232, FN: 110
# Sensitivity: 0.7804, Specificity: 0.6844, F1-Score: 0.7828
# ================================================================
# Train Epoch: 22 [3358/3358 (100.00%)]  Accuracy: 79.12%  Loss: 0.6670
# Test set: Accuracy: 74.64%  Loss: 0.6892
# TP: 386, FP: 98, TN: 241, FN: 115
# Sensitivity: 0.7705, Specificity: 0.7109, F1-Score: 0.7838
# ================================================================
# Train Epoch: 23 [3358/3358 (100.00%)]  Accuracy: 78.95%  Loss: 0.6682
# Test set: Accuracy: 72.86%  Loss: 0.6984
# TP: 389, FP: 116, TN: 223, FN: 112
# Sensitivity: 0.7764, Specificity: 0.6578, F1-Score: 0.7734
# ================================================================
# Train Epoch: 24 [3358/3358 (100.00%)]  Accuracy: 79.66%  Loss: 0.6663
# Test set: Accuracy: 74.17%  Loss: 0.6926
# TP: 404, FP: 120, TN: 219, FN: 97
# Sensitivity: 0.8064, Specificity: 0.6460, F1-Score: 0.7883
# ================================================================
# Train Epoch: 25 [3358/3358 (100.00%)]  Accuracy: 79.90%  Loss: 0.6646
# Test set: Accuracy: 74.05%  Loss: 0.6961
# TP: 403, FP: 120, TN: 219, FN: 98
# Sensitivity: 0.8044, Specificity: 0.6460, F1-Score: 0.7871
# ================================================================
# Train Epoch: 26 [3358/3358 (100.00%)]  Accuracy: 80.49%  Loss: 0.6603
# Test set: Accuracy: 74.40%  Loss: 0.6912
# TP: 390, FP: 104, TN: 235, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6932, F1-Score: 0.7839
# ================================================================
# Train Epoch: 27 [3358/3358 (100.00%)]  Accuracy: 80.70%  Loss: 0.6598
# Test set: Accuracy: 75.00%  Loss: 0.6898
# TP: 393, FP: 102, TN: 237, FN: 108
# Sensitivity: 0.7844, Specificity: 0.6991, F1-Score: 0.7892
# ================================================================
# Train Epoch: 28 [3358/3358 (100.00%)]  Accuracy: 81.33%  Loss: 0.6562
# Test set: Accuracy: 74.05%  Loss: 0.6921
# TP: 383, FP: 100, TN: 239, FN: 118
# Sensitivity: 0.7645, Specificity: 0.7050, F1-Score: 0.7785
# Epoch 00028: reducing learning rate of group 0 to 1.0000e-06.
# ================================================================
# Train Epoch: 29 [3358/3358 (100.00%)]  Accuracy: 81.42%  Loss: 0.6539
# Test set: Accuracy: 72.26%  Loss: 0.7009
# TP: 369, FP: 101, TN: 238, FN: 132
# Sensitivity: 0.7365, Specificity: 0.7021, F1-Score: 0.7600
# ================================================================
# Train Epoch: 30 [3358/3358 (100.00%)]  Accuracy: 81.89%  Loss: 0.6520
# Test set: Accuracy: 76.07%  Loss: 0.6832
# TP: 397, FP: 97, TN: 242, FN: 104
# Sensitivity: 0.7924, Specificity: 0.7139, F1-Score: 0.7980
# ================================================================
# Train Epoch: 31 [3358/3358 (100.00%)]  Accuracy: 82.46%  Loss: 0.6495
# Test set: Accuracy: 74.52%  Loss: 0.6901
# TP: 395, FP: 108, TN: 231, FN: 106
# Sensitivity: 0.7884, Specificity: 0.6814, F1-Score: 0.7869
# ================================================================
# Train Epoch: 32 [3358/3358 (100.00%)]  Accuracy: 81.75%  Loss: 0.6533
# Test set: Accuracy: 75.00%  Loss: 0.6879
# TP: 389, FP: 98, TN: 241, FN: 112
# Sensitivity: 0.7764, Specificity: 0.7109, F1-Score: 0.7874
# ================================================================
# Train Epoch: 33 [3358/3358 (100.00%)]  Accuracy: 82.04%  Loss: 0.6509
# Test set: Accuracy: 75.12%  Loss: 0.6902
# TP: 402, FP: 110, TN: 229, FN: 99
# Sensitivity: 0.8024, Specificity: 0.6755, F1-Score: 0.7937
# ================================================================
# Train Epoch: 34 [3358/3358 (100.00%)]  Accuracy: 82.67%  Loss: 0.6489
# Test set: Accuracy: 75.00%  Loss: 0.6882
# TP: 389, FP: 98, TN: 241, FN: 112
# Sensitivity: 0.7764, Specificity: 0.7109, F1-Score: 0.7874
# ================================================================
# Train Epoch: 35 [3358/3358 (100.00%)]  Accuracy: 82.37%  Loss: 0.6490
# Test set: Accuracy: 74.52%  Loss: 0.6916
# TP: 401, FP: 114, TN: 225, FN: 100
# Sensitivity: 0.8004, Specificity: 0.6637, F1-Score: 0.7894
# ================================================================
# Train Epoch: 36 [3358/3358 (100.00%)]  Accuracy: 82.19%  Loss: 0.6508
# Test set: Accuracy: 75.00%  Loss: 0.6881
# TP: 397, FP: 106, TN: 233, FN: 104
# Sensitivity: 0.7924, Specificity: 0.6873, F1-Score: 0.7908
# Epoch 00036: reducing learning rate of group 0 to 1.0000e-07.
# ================================================================
# Train Epoch: 37 [3358/3358 (100.00%)]  Accuracy: 82.40%  Loss: 0.6511
# Test set: Accuracy: 74.40%  Loss: 0.6901
# TP: 395, FP: 109, TN: 230, FN: 106
# Sensitivity: 0.7884, Specificity: 0.6785, F1-Score: 0.7861
# ================================================================
# Train Epoch: 38 [3358/3358 (100.00%)]  Accuracy: 81.83%  Loss: 0.6520
# Test set: Accuracy: 73.81%  Loss: 0.6931
# TP: 396, FP: 115, TN: 224, FN: 105
# Sensitivity: 0.7904, Specificity: 0.6608, F1-Score: 0.7826
# ================================================================
# Train Epoch: 39 [3358/3358 (100.00%)]  Accuracy: 81.48%  Loss: 0.6541
# Test set: Accuracy: 74.05%  Loss: 0.6906
# TP: 377, FP: 94, TN: 245, FN: 124
# Sensitivity: 0.7525, Specificity: 0.7227, F1-Score: 0.7757
# ================================================================
# Train Epoch: 40 [3358/3358 (100.00%)]  Accuracy: 81.92%  Loss: 0.6510
# Test set: Accuracy: 75.48%  Loss: 0.6857
# TP: 391, FP: 96, TN: 243, FN: 110
# Sensitivity: 0.7804, Specificity: 0.7168, F1-Score: 0.7915
# ================================================================
# Train Epoch: 41 [3358/3358 (100.00%)]  Accuracy: 82.82%  Loss: 0.6482
# Test set: Accuracy: 73.81%  Loss: 0.6938
# TP: 380, FP: 99, TN: 240, FN: 121
# Sensitivity: 0.7585, Specificity: 0.7080, F1-Score: 0.7755
# ================================================================
# Train Epoch: 42 [3358/3358 (100.00%)]  Accuracy: 82.19%  Loss: 0.6512
# Test set: Accuracy: 74.05%  Loss: 0.6918
# TP: 384, FP: 101, TN: 238, FN: 117
# Sensitivity: 0.7665, Specificity: 0.7021, F1-Score: 0.7789
# Epoch 00042: reducing learning rate of group 0 to 1.0000e-08.
# ================================================================
# Train Epoch: 43 [3358/3358 (100.00%)]  Accuracy: 82.88%  Loss: 0.6471
# Test set: Accuracy: 73.81%  Loss: 0.6904
# TP: 402, FP: 121, TN: 218, FN: 99
# Sensitivity: 0.8024, Specificity: 0.6431, F1-Score: 0.7852
# ================================================================
# Train Epoch: 44 [3358/3358 (100.00%)]  Accuracy: 81.83%  Loss: 0.6532
# Test set: Accuracy: 74.88%  Loss: 0.6898
# TP: 388, FP: 98, TN: 241, FN: 113
# Sensitivity: 0.7745, Specificity: 0.7109, F1-Score: 0.7862
# ================================================================
# Train Epoch: 45 [3358/3358 (100.00%)]  Accuracy: 81.92%  Loss: 0.6532
# Test set: Accuracy: 73.10%  Loss: 0.6964
# TP: 388, FP: 113, TN: 226, FN: 113
# Sensitivity: 0.7745, Specificity: 0.6667, F1-Score: 0.7745
# ================================================================
# Train Epoch: 46 [3358/3358 (100.00%)]  Accuracy: 82.10%  Loss: 0.6512
# Test set: Accuracy: 75.00%  Loss: 0.6875
# TP: 386, FP: 95, TN: 244, FN: 115
# Sensitivity: 0.7705, Specificity: 0.7198, F1-Score: 0.7862
# ================================================================
# Train Epoch: 47 [3358/3358 (100.00%)]  Accuracy: 82.22%  Loss: 0.6502
# Test set: Accuracy: 74.17%  Loss: 0.6922
# TP: 394, FP: 110, TN: 229, FN: 107
# Sensitivity: 0.7864, Specificity: 0.6755, F1-Score: 0.7841
# ================================================================
# Train Epoch: 48 [3358/3358 (100.00%)]  Accuracy: 82.55%  Loss: 0.6497
# Test set: Accuracy: 74.17%  Loss: 0.6945
# TP: 400, FP: 116, TN: 223, FN: 101
# Sensitivity: 0.7984, Specificity: 0.6578, F1-Score: 0.7866
# ================================================================
# Train Epoch: 49 [3358/3358 (100.00%)]  Accuracy: 82.13%  Loss: 0.6506
# Test set: Accuracy: 74.40%  Loss: 0.6927
# TP: 399, FP: 113, TN: 226, FN: 102
# Sensitivity: 0.7964, Specificity: 0.6667, F1-Score: 0.7878
# ================================================================
# Train Epoch: 50 [3358/3358 (100.00%)]  Accuracy: 81.51%  Loss: 0.6540
# Test set: Accuracy: 74.88%  Loss: 0.6878
# TP: 390, FP: 100, TN: 239, FN: 111
# Sensitivity: 0.7784, Specificity: 0.7050, F1-Score: 0.7871
# ================================================================
# Train Epoch: 51 [3358/3358 (100.00%)]  Accuracy: 82.49%  Loss: 0.6474
# Test set: Accuracy: 73.69%  Loss: 0.6944
# TP: 387, FP: 107, TN: 232, FN: 114
# Sensitivity: 0.7725, Specificity: 0.6844, F1-Score: 0.7779
# ================================================================
# Train Epoch: 52 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6503
# Test set: Accuracy: 74.88%  Loss: 0.6911
# TP: 419, FP: 129, TN: 210, FN: 82
# Sensitivity: 0.8363, Specificity: 0.6195, F1-Score: 0.7989
# ================================================================
# Train Epoch: 53 [3358/3358 (100.00%)]  Accuracy: 81.48%  Loss: 0.6548
# Test set: Accuracy: 73.69%  Loss: 0.6931
# TP: 373, FP: 93, TN: 246, FN: 128
# Sensitivity: 0.7445, Specificity: 0.7257, F1-Score: 0.7715
# ================================================================
# Train Epoch: 54 [3358/3358 (100.00%)]  Accuracy: 81.63%  Loss: 0.6539
# Test set: Accuracy: 74.05%  Loss: 0.6937
# TP: 387, FP: 104, TN: 235, FN: 114
# Sensitivity: 0.7725, Specificity: 0.6932, F1-Score: 0.7802
# ================================================================
# Train Epoch: 55 [3358/3358 (100.00%)]  Accuracy: 82.19%  Loss: 0.6503
# Test set: Accuracy: 74.52%  Loss: 0.6909
# TP: 392, FP: 105, TN: 234, FN: 109
# Sensitivity: 0.7824, Specificity: 0.6903, F1-Score: 0.7856
# ================================================================
# Train Epoch: 56 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6502
# Test set: Accuracy: 74.52%  Loss: 0.6910
# TP: 389, FP: 102, TN: 237, FN: 112
# Sensitivity: 0.7764, Specificity: 0.6991, F1-Score: 0.7843
# ================================================================
# Train Epoch: 57 [3358/3358 (100.00%)]  Accuracy: 81.69%  Loss: 0.6540
# Test set: Accuracy: 74.76%  Loss: 0.6890
# TP: 403, FP: 114, TN: 225, FN: 98
# Sensitivity: 0.8044, Specificity: 0.6637, F1-Score: 0.7917
# ================================================================
# Train Epoch: 58 [3358/3358 (100.00%)]  Accuracy: 81.95%  Loss: 0.6520
# Test set: Accuracy: 74.17%  Loss: 0.6921
# TP: 404, FP: 120, TN: 219, FN: 97
# Sensitivity: 0.8064, Specificity: 0.6460, F1-Score: 0.7883
# ================================================================
# Train Epoch: 59 [3358/3358 (100.00%)]  Accuracy: 82.52%  Loss: 0.6487
# Test set: Accuracy: 74.05%  Loss: 0.6963
# TP: 406, FP: 123, TN: 216, FN: 95
# Sensitivity: 0.8104, Specificity: 0.6372, F1-Score: 0.7883
# ================================================================
# Train Epoch: 60 [3358/3358 (100.00%)]  Accuracy: 81.63%  Loss: 0.6541
# Test set: Accuracy: 73.69%  Loss: 0.6955
# TP: 388, FP: 108, TN: 231, FN: 113
# Sensitivity: 0.7745, Specificity: 0.6814, F1-Score: 0.7783
# ================================================================
# Train Epoch: 61 [3358/3358 (100.00%)]  Accuracy: 82.64%  Loss: 0.6491
# Test set: Accuracy: 74.52%  Loss: 0.6875
# TP: 387, FP: 100, TN: 239, FN: 114
# Sensitivity: 0.7725, Specificity: 0.7050, F1-Score: 0.7834
# ================================================================
# Train Epoch: 62 [3358/3358 (100.00%)]  Accuracy: 82.37%  Loss: 0.6491
# Test set: Accuracy: 74.52%  Loss: 0.6942
# TP: 402, FP: 115, TN: 224, FN: 99
# Sensitivity: 0.8024, Specificity: 0.6608, F1-Score: 0.7898
# ================================================================
# Train Epoch: 63 [3358/3358 (100.00%)]  Accuracy: 81.83%  Loss: 0.6514
# Test set: Accuracy: 75.24%  Loss: 0.6882
# TP: 392, FP: 99, TN: 240, FN: 109
# Sensitivity: 0.7824, Specificity: 0.7080, F1-Score: 0.7903
# ================================================================
# Train Epoch: 64 [3358/3358 (100.00%)]  Accuracy: 81.72%  Loss: 0.6524
# Test set: Accuracy: 74.05%  Loss: 0.6937
# TP: 390, FP: 107, TN: 232, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6844, F1-Score: 0.7816
# ================================================================
# Train Epoch: 65 [3358/3358 (100.00%)]  Accuracy: 82.13%  Loss: 0.6509
# Test set: Accuracy: 74.05%  Loss: 0.6953
# TP: 390, FP: 107, TN: 232, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6844, F1-Score: 0.7816
# ================================================================
# Train Epoch: 66 [3358/3358 (100.00%)]  Accuracy: 82.01%  Loss: 0.6529
# Test set: Accuracy: 75.00%  Loss: 0.6887
# TP: 385, FP: 94, TN: 245, FN: 116
# Sensitivity: 0.7685, Specificity: 0.7227, F1-Score: 0.7857
# ================================================================
# Train Epoch: 67 [3358/3358 (100.00%)]  Accuracy: 81.89%  Loss: 0.6521
# Test set: Accuracy: 75.48%  Loss: 0.6886
# TP: 402, FP: 107, TN: 232, FN: 99
# Sensitivity: 0.8024, Specificity: 0.6844, F1-Score: 0.7960
# ================================================================
# Train Epoch: 68 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6500
# Test set: Accuracy: 74.64%  Loss: 0.6912
# TP: 388, FP: 100, TN: 239, FN: 113
# Sensitivity: 0.7745, Specificity: 0.7050, F1-Score: 0.7846
# ================================================================
# Train Epoch: 69 [3358/3358 (100.00%)]  Accuracy: 82.04%  Loss: 0.6509
# Test set: Accuracy: 73.57%  Loss: 0.6949
# TP: 387, FP: 108, TN: 231, FN: 114
# Sensitivity: 0.7725, Specificity: 0.6814, F1-Score: 0.7771
# ================================================================
# Train Epoch: 70 [3358/3358 (100.00%)]  Accuracy: 82.22%  Loss: 0.6521
# Test set: Accuracy: 74.76%  Loss: 0.6905
# TP: 389, FP: 100, TN: 239, FN: 112
# Sensitivity: 0.7764, Specificity: 0.7050, F1-Score: 0.7859
# ================================================================
# Train Epoch: 71 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6496
# Test set: Accuracy: 74.05%  Loss: 0.6924
# TP: 388, FP: 105, TN: 234, FN: 113
# Sensitivity: 0.7745, Specificity: 0.6903, F1-Score: 0.7807
# ================================================================
# Train Epoch: 72 [3358/3358 (100.00%)]  Accuracy: 82.76%  Loss: 0.6470
# Test set: Accuracy: 72.86%  Loss: 0.6989
# TP: 377, FP: 104, TN: 235, FN: 124
# Sensitivity: 0.7525, Specificity: 0.6932, F1-Score: 0.7678
# ================================================================
# Train Epoch: 73 [3358/3358 (100.00%)]  Accuracy: 82.55%  Loss: 0.6498
# Test set: Accuracy: 75.00%  Loss: 0.6900
# TP: 389, FP: 98, TN: 241, FN: 112
# Sensitivity: 0.7764, Specificity: 0.7109, F1-Score: 0.7874
# ================================================================
# Train Epoch: 74 [3358/3358 (100.00%)]  Accuracy: 81.75%  Loss: 0.6517
# Test set: Accuracy: 75.00%  Loss: 0.6880
# TP: 396, FP: 105, TN: 234, FN: 105
# Sensitivity: 0.7904, Specificity: 0.6903, F1-Score: 0.7904
# ================================================================
# Train Epoch: 75 [3358/3358 (100.00%)]  Accuracy: 82.28%  Loss: 0.6504
# Test set: Accuracy: 74.17%  Loss: 0.6919
# TP: 395, FP: 111, TN: 228, FN: 106
# Sensitivity: 0.7884, Specificity: 0.6726, F1-Score: 0.7845
# ================================================================
# Train Epoch: 76 [3358/3358 (100.00%)]  Accuracy: 82.82%  Loss: 0.6478
# Test set: Accuracy: 75.12%  Loss: 0.6878
# TP: 405, FP: 113, TN: 226, FN: 96
# Sensitivity: 0.8084, Specificity: 0.6667, F1-Score: 0.7949
# ================================================================
# Train Epoch: 77 [3358/3358 (100.00%)]  Accuracy: 82.85%  Loss: 0.6486
# Test set: Accuracy: 75.60%  Loss: 0.6845
# TP: 404, FP: 108, TN: 231, FN: 97
# Sensitivity: 0.8064, Specificity: 0.6814, F1-Score: 0.7976
# ================================================================
# Train Epoch: 78 [3358/3358 (100.00%)]  Accuracy: 81.72%  Loss: 0.6523
# Test set: Accuracy: 74.88%  Loss: 0.6880
# TP: 397, FP: 107, TN: 232, FN: 104
# Sensitivity: 0.7924, Specificity: 0.6844, F1-Score: 0.7900
# ================================================================
# Train Epoch: 79 [3358/3358 (100.00%)]  Accuracy: 82.82%  Loss: 0.6470
# Test set: Accuracy: 73.69%  Loss: 0.6945
# TP: 383, FP: 103, TN: 236, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6962, F1-Score: 0.7761
# ================================================================
# Train Epoch: 80 [3358/3358 (100.00%)]  Accuracy: 82.31%  Loss: 0.6514
# Test set: Accuracy: 74.52%  Loss: 0.6895
# TP: 391, FP: 104, TN: 235, FN: 110
# Sensitivity: 0.7804, Specificity: 0.6932, F1-Score: 0.7851
# ================================================================
# Train Epoch: 81 [3358/3358 (100.00%)]  Accuracy: 81.83%  Loss: 0.6518
# Test set: Accuracy: 73.45%  Loss: 0.6969
# TP: 384, FP: 106, TN: 233, FN: 117
# Sensitivity: 0.7665, Specificity: 0.6873, F1-Score: 0.7750
# ================================================================
# Train Epoch: 82 [3358/3358 (100.00%)]  Accuracy: 82.82%  Loss: 0.6476
# Test set: Accuracy: 74.40%  Loss: 0.6926
# TP: 394, FP: 108, TN: 231, FN: 107
# Sensitivity: 0.7864, Specificity: 0.6814, F1-Score: 0.7856
# ================================================================
# Train Epoch: 83 [3358/3358 (100.00%)]  Accuracy: 81.75%  Loss: 0.6526
# Test set: Accuracy: 72.62%  Loss: 0.6996
# TP: 378, FP: 107, TN: 232, FN: 123
# Sensitivity: 0.7545, Specificity: 0.6844, F1-Score: 0.7667
# ================================================================
# Train Epoch: 84 [3358/3358 (100.00%)]  Accuracy: 81.89%  Loss: 0.6530
# Test set: Accuracy: 75.24%  Loss: 0.6861
# TP: 398, FP: 105, TN: 234, FN: 103
# Sensitivity: 0.7944, Specificity: 0.6903, F1-Score: 0.7928
# ================================================================
# Train Epoch: 85 [3358/3358 (100.00%)]  Accuracy: 82.55%  Loss: 0.6496
# Test set: Accuracy: 75.12%  Loss: 0.6848
# TP: 394, FP: 102, TN: 237, FN: 107
# Sensitivity: 0.7864, Specificity: 0.6991, F1-Score: 0.7904
# ================================================================
# Train Epoch: 86 [3358/3358 (100.00%)]  Accuracy: 81.75%  Loss: 0.6521
# Test set: Accuracy: 74.64%  Loss: 0.6866
# TP: 385, FP: 97, TN: 242, FN: 116
# Sensitivity: 0.7685, Specificity: 0.7139, F1-Score: 0.7833
# ================================================================
# Train Epoch: 87 [3358/3358 (100.00%)]  Accuracy: 82.91%  Loss: 0.6478
# Test set: Accuracy: 74.40%  Loss: 0.6882
# TP: 390, FP: 104, TN: 235, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6932, F1-Score: 0.7839
# ================================================================
# Train Epoch: 88 [3358/3358 (100.00%)]  Accuracy: 82.25%  Loss: 0.6508
# Test set: Accuracy: 74.29%  Loss: 0.6912
# TP: 386, FP: 101, TN: 238, FN: 115
# Sensitivity: 0.7705, Specificity: 0.7021, F1-Score: 0.7814
# ================================================================
# Train Epoch: 89 [3358/3358 (100.00%)]  Accuracy: 82.43%  Loss: 0.6506
# Test set: Accuracy: 74.29%  Loss: 0.6915
# TP: 391, FP: 106, TN: 233, FN: 110
# Sensitivity: 0.7804, Specificity: 0.6873, F1-Score: 0.7836
# ================================================================
# Train Epoch: 90 [3358/3358 (100.00%)]  Accuracy: 81.83%  Loss: 0.6522
# Test set: Accuracy: 73.81%  Loss: 0.6959
# TP: 404, FP: 123, TN: 216, FN: 97
# Sensitivity: 0.8064, Specificity: 0.6372, F1-Score: 0.7860
# ================================================================
# Train Epoch: 91 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6508
# Test set: Accuracy: 76.07%  Loss: 0.6821
# TP: 400, FP: 100, TN: 239, FN: 101
# Sensitivity: 0.7984, Specificity: 0.7050, F1-Score: 0.7992
# ================================================================
# Train Epoch: 92 [3358/3358 (100.00%)]  Accuracy: 82.76%  Loss: 0.6475
# Test set: Accuracy: 75.95%  Loss: 0.6844
# TP: 399, FP: 100, TN: 239, FN: 102
# Sensitivity: 0.7964, Specificity: 0.7050, F1-Score: 0.7980
# ================================================================
# Train Epoch: 93 [3358/3358 (100.00%)]  Accuracy: 81.77%  Loss: 0.6531
# Test set: Accuracy: 73.10%  Loss: 0.6971
# TP: 381, FP: 106, TN: 233, FN: 120
# Sensitivity: 0.7605, Specificity: 0.6873, F1-Score: 0.7713
# ================================================================
# Train Epoch: 94 [3358/3358 (100.00%)]  Accuracy: 82.91%  Loss: 0.6475
# Test set: Accuracy: 74.17%  Loss: 0.6921
# TP: 391, FP: 107, TN: 232, FN: 110
# Sensitivity: 0.7804, Specificity: 0.6844, F1-Score: 0.7828
# ================================================================
# Train Epoch: 95 [3358/3358 (100.00%)]  Accuracy: 82.37%  Loss: 0.6500
# Test set: Accuracy: 73.57%  Loss: 0.6967
# TP: 403, FP: 124, TN: 215, FN: 98
# Sensitivity: 0.8044, Specificity: 0.6342, F1-Score: 0.7840
# ================================================================
# Train Epoch: 96 [3358/3358 (100.00%)]  Accuracy: 81.98%  Loss: 0.6523
# Test set: Accuracy: 74.76%  Loss: 0.6910
# TP: 409, FP: 120, TN: 219, FN: 92
# Sensitivity: 0.8164, Specificity: 0.6460, F1-Score: 0.7942
# ================================================================
# Train Epoch: 97 [3358/3358 (100.00%)]  Accuracy: 82.37%  Loss: 0.6513
# Test set: Accuracy: 74.05%  Loss: 0.6943
# TP: 383, FP: 100, TN: 239, FN: 118
# Sensitivity: 0.7645, Specificity: 0.7050, F1-Score: 0.7785
# ================================================================
# Train Epoch: 98 [3358/3358 (100.00%)]  Accuracy: 81.86%  Loss: 0.6521
# Test set: Accuracy: 74.88%  Loss: 0.6886
# TP: 384, FP: 94, TN: 245, FN: 117
# Sensitivity: 0.7665, Specificity: 0.7227, F1-Score: 0.7845
# ================================================================
# Train Epoch: 99 [3358/3358 (100.00%)]  Accuracy: 82.73%  Loss: 0.6486
# Test set: Accuracy: 74.29%  Loss: 0.6920
# TP: 390, FP: 105, TN: 234, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6903, F1-Score: 0.7831
# ================================================================
# Train Epoch: 100 [3358/3358 (100.00%)]  Accuracy: 82.61%  Loss: 0.6483
# Test set: Accuracy: 75.12%  Loss: 0.6902
# TP: 390, FP: 98, TN: 241, FN: 111
# Sensitivity: 0.7784, Specificity: 0.7109, F1-Score: 0.7887
# ================================================================

# %%
accs_np = np.array(accs)
losses_np = np.array(losses)
np.save('./mix_strong_acc_.npy', accs_np)
np.save('./mix_strong_loss_.npy', losses_np)

torch.save(best_acc_model, './mix_strong_best_acc_model_.pt')
torch.save(best_acc_model_state, './mix_strong_best_acc_model_state_.pt')
torch.save(best_f1_model, './mix_strong_best_f1_model_.pt')
torch.save(best_f1_model_state, './mix_strong_best_f1_model_state_.pt')
