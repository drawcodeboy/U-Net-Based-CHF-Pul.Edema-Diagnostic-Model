# %%
import torch
from torch import nn
from torchvision import transforms
from torchvision import models
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFilter
from PIL import ImageOps
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
from copy import copy
from copy import deepcopy
import sys
import os
import pandas as pd
import numpy as np
import random
from pathlib import Path

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True' # dead kernel for matplotlib

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
metadata = pd.read_csv('../doby_meta.csv')
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7064 entries, 0 to 7063
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      7064 non-null   int64
#  1   study_id        7064 non-null   int64
#  2   dicom_id        7064 non-null   object
#  3   DicomPath       7064 non-null   object
#  4   edema_severity  7064 non-null   int64
#  5   normal          7064 non-null   int64
#  6   CHF             7064 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 338.2+ KB

# %%
metadata = metadata[metadata['subject_id'] < 16000000]
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4198 entries, 0 to 4197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      4198 non-null   int64
#  1   study_id        4198 non-null   int64
#  2   dicom_id        4198 non-null   object
#  3   DicomPath       4198 non-null   object
#  4   edema_severity  4198 non-null   int64
#  5   normal          4198 non-null   int64
#  6   CHF             4198 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 233.7+ KB

# %%
ORIG_BASE_PATH = '../physionet.org/files/mimic-cxr-jpg/2.0.0'

# %%
class Resize(object):
    def __init__(self, size):
        self.size = size

    def __call__(self, x_seg, x_orig):
        return x_seg, x_orig.resize((self.size, self.size))

ORIG_TRANSFORMS = transforms.Compose([
    transforms.ToTensor()
])

# %%
class Dataset(Dataset):
    def __init__(self, metadata, orig_base_path, transform=None):
        self.metadata = metadata
        self.orig_base_path = Path(orig_base_path)
        self.transform = transform

    def __getitem__(self, idx):
        x_path = self.metadata.loc[idx, 'DicomPath']
        x_orig_path = self.orig_base_path / Path(x_path)
        
        x_orig = Image.open(x_orig_path).convert('L').resize((224, 224))

        x_orig = x_orig.filter(ImageFilter.GaussianBlur(1))

        x_orig = ImageOps.equalize(x_orig)
        
        y = self.metadata.loc[idx, 'normal']

        if self.transform:
            x = self.transform(x_orig)

        return x, y

    def __len__(self):
        return self.metadata['normal'].count()

# %%
orig_ds = Dataset(metadata, ORIG_BASE_PATH, transform=ORIG_TRANSFORMS)

# %%
from torchvision.transforms.functional import to_pil_image

x, y = orig_ds[201]
plt.title(y)
plt.imshow(to_pil_image(x), cmap='gray')
plt.axis('off')
plt.show()

# %%
ds_size = len(orig_ds)
train_size = int(ds_size * 0.8)
test_size = ds_size - train_size
orig_train, orig_test = random_split(orig_ds, [train_size, test_size], generator=torch.manual_seed(42))

# %%
print(len(orig_train), len(orig_test))
# Out:
# 3358 840

# %%
orig_train = copy(orig_train)

TRAIN_TRANSFORM = transforms.Compose([
    transforms.ToTensor(),
    # rotation degree = -10, 10
    # translate -img_width * a < dx < img_width * a
        # -11.2 < dx < 11.2, y도 b로 마찬가지, tuple 형태로
    transforms.RandomAffine(degrees=10, translate=(0.05, 0.05))
])

orig_train.dataset.transform = TRAIN_TRANSFORM

# %%
orig_train_dl = DataLoader(orig_train, batch_size=16, shuffle=True)
orig_test_dl = DataLoader(orig_test, batch_size=8, shuffle=True)

# %%
class customDenseNet(nn.Module):
    def __init__(self):
        super(customDenseNet, self).__init__()
        self.model = models.densenet121(weights='IMAGENET1K_V1')
        self.model.features.conv0 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.linear = nn.Linear(1000, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.model(x)
        x = self.linear(x)
        x = self.sigmoid(x)

        return x

# %%
orig_net = customDenseNet()
orig_net.to(device)
# Out:
# customDenseNet(
#   (model): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition1): _Transition(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock2): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition2): _Transition(
#         (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock3): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition3): _Transition(
#         (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock4): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (classifier): Linear(in_features=1024, out_features=1000, bias=True)
#   )
#   (linear): Linear(in_features=1000, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
optimizer = torch.optim.Adam(orig_net.parameters(), lr=0.0001)
schedular = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
weights = (metadata['normal'] == 0).sum() / (metadata['normal'] == 1).sum()
loss_fn = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([weights])).to(device)

# %%
def train(model, data_loader, optimizer, epoch):
    model.train()
    running_loss = 0
    running_acc = 0
    n_data = 0

    for batch_idx, (batch, target) in enumerate(data_loader, start=1):
        batch, target = batch.to(device), target.to(device)

        optimizer.zero_grad()

        output = model(batch)
        # print(output.shape, target.shape)
        target_ = target
        target = target.unsqueeze(dim=-1).float()

        loss = loss_fn(output, target)
        running_loss += loss.item()

        predicted = (output >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)
        correct = (predicted == target).sum().item()
        running_acc += correct

        loss.backward()
        optimizer.step()

        n_data += len(batch)
        print(f'\rTrain Epoch: {epoch} [{n_data}/{len(data_loader.dataset)} ({100 * batch_idx / len(data_loader):.2f}%)]  Accuracy: {100*running_acc/n_data:.2f}%  Loss: {running_loss/batch_idx:.4f}', end='')

# %%
TP, FP, TN, FN = 0, 0, 0, 0

predicted = torch.Tensor([[1], [0], [0], [1]]).float()
target = torch.Tensor([[0], [1], [0], [1]]).float()

TP += ((predicted == target) & (target == 1)).sum().item()
FP += ((predicted != target) & (target == 0)).sum().item()
TN += ((predicted == target) & (target == 0)).sum().item()
FN += ((predicted != target) & (target == 1)).sum().item()

print(TP, FP, TN, FN)
# Out:
# 1 1 1 1

# %%
def test(model, data_loader):
    model.eval()
    test_acc = 0
    test_loss = 0
    n_data = 0
    TP, FP, TN, FN = 0, 0, 0, 0
    with torch.no_grad():
        for batch, target in data_loader:
            batch, target = batch.to(device), target.to(device)

            output = model(batch)
            target = target.unsqueeze(dim=-1).float()

            loss = loss_fn(output, target)
            test_loss += loss.item()

            predicted = (output >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)
            correct = (predicted == target).sum().item()
            test_acc += correct

            TP += ((predicted == target) & (target == 1)).sum().item()
            FP += ((predicted != target) & (target == 0)).sum().item()
            TN += ((predicted == target) & (target == 0)).sum().item()
            FN += ((predicted != target) & (target == 1)).sum().item()
            
            n_data += len(batch)
            print(f'\rTest set: [{100*n_data/len(data_loader.dataset):.2f}%]', end='')
    
    test_acc = 100 * test_acc / len(data_loader.dataset)
    test_loss = test_loss / len(data_loader)
    
    print(f'\rTest set: Accuracy: {test_acc:.2f}%  Loss: {test_loss:.4f}')

    return test_acc, test_loss, TP, FP, TN, FN

# %%
def getMetric(TP, FP, TN, FN):
    # base case: divide by zero
    TP = 0.1 if TP == 0 else TP
    FP = 0.1 if FP == 0 else FP
    TN = 0.1 if TN == 0 else TN
    FN = 0.1 if FN == 0 else FN
    
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    f1_score = 2*precision*recall/(precision+recall)
    return sensitivity, specificity, f1_score

# %%
accs = []
losses = []
best_acc = 0
best_f1 = 0

best_acc_model = None
best_acc_model_state = None
best_f1_model = None
best_f1_model_state = None

# %%
for epoch in range(1, 100+1):
    train(orig_net, orig_train_dl, optimizer, epoch)
    
    print()
    
    acc, loss, tp, fp, tn, fn = test(orig_net, orig_test_dl)
    sensitivity, specificity, f1_score = getMetric(tp, fp, tn, fn)
    print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')
    print(f'Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, F1-Score: {f1_score:.4f}')

    if acc > best_acc:
        best_acc = acc
        best_acc_model = deepcopy(orig_net)
        best_acc_model_state = deepcopy(orig_net.state_dict())

    if f1_score > best_f1:
        best_f1 = f1_score
        best_f1_model = deepcopy(orig_net)
        best_f1_model_state = deepcopy(orig_net.state_dict())
        
    schedular.step(loss)
    accs.append(acc)
    losses.append(loss)

    print('================================================================')
# Out:
# Train Epoch: 1 [3358/3358 (100.00%)]  Accuracy: 64.65%  Loss: 0.7487
# Test set: Accuracy: 68.21%  Loss: 0.7278
# TP: 383, FP: 149, TN: 190, FN: 118
# Sensitivity: 0.7645, Specificity: 0.5605, F1-Score: 0.7415
# ================================================================
# Train Epoch: 2 [3358/3358 (100.00%)]  Accuracy: 67.21%  Loss: 0.7335
# Test set: Accuracy: 68.69%  Loss: 0.7295
# TP: 440, FP: 202, TN: 137, FN: 61
# Sensitivity: 0.8782, Specificity: 0.4041, F1-Score: 0.7699
# ================================================================
# Train Epoch: 3 [3358/3358 (100.00%)]  Accuracy: 69.86%  Loss: 0.7221
# Test set: Accuracy: 69.88%  Loss: 0.7142
# TP: 341, FP: 93, TN: 246, FN: 160
# Sensitivity: 0.6806, Specificity: 0.7257, F1-Score: 0.7294
# ================================================================
# Train Epoch: 4 [3358/3358 (100.00%)]  Accuracy: 68.97%  Loss: 0.7221
# Test set: Accuracy: 71.43%  Loss: 0.7112
# TP: 416, FP: 155, TN: 184, FN: 85
# Sensitivity: 0.8303, Specificity: 0.5428, F1-Score: 0.7761
# ================================================================
# Train Epoch: 5 [3358/3358 (100.00%)]  Accuracy: 70.31%  Loss: 0.7195
# Test set: Accuracy: 62.38%  Loss: 0.7563
# TP: 312, FP: 127, TN: 212, FN: 189
# Sensitivity: 0.6228, Specificity: 0.6254, F1-Score: 0.6638
# ================================================================
# Train Epoch: 6 [3358/3358 (100.00%)]  Accuracy: 68.55%  Loss: 0.7283
# Test set: Accuracy: 65.24%  Loss: 0.7365
# TP: 286, FP: 77, TN: 262, FN: 215
# Sensitivity: 0.5709, Specificity: 0.7729, F1-Score: 0.6620
# ================================================================
# Train Epoch: 7 [3358/3358 (100.00%)]  Accuracy: 70.19%  Loss: 0.7202
# Test set: Accuracy: 61.19%  Loss: 0.7589
# TP: 242, FP: 67, TN: 272, FN: 259
# Sensitivity: 0.4830, Specificity: 0.8024, F1-Score: 0.5975
# ================================================================
# Train Epoch: 8 [3358/3358 (100.00%)]  Accuracy: 69.98%  Loss: 0.7187
# Test set: Accuracy: 70.24%  Loss: 0.7168
# TP: 421, FP: 170, TN: 169, FN: 80
# Sensitivity: 0.8403, Specificity: 0.4985, F1-Score: 0.7711
# ================================================================
# Train Epoch: 9 [3358/3358 (100.00%)]  Accuracy: 71.20%  Loss: 0.7115
# Test set: Accuracy: 70.00%  Loss: 0.7218
# TP: 425, FP: 176, TN: 163, FN: 76
# Sensitivity: 0.8483, Specificity: 0.4808, F1-Score: 0.7713
# ================================================================
# Train Epoch: 10 [3358/3358 (100.00%)]  Accuracy: 71.98%  Loss: 0.7087
# Test set: Accuracy: 68.10%  Loss: 0.7247
# TP: 340, FP: 107, TN: 232, FN: 161
# Sensitivity: 0.6786, Specificity: 0.6844, F1-Score: 0.7173
# Epoch 00010: reducing learning rate of group 0 to 1.0000e-05.
# ================================================================
# Train Epoch: 11 [3358/3358 (100.00%)]  Accuracy: 72.13%  Loss: 0.7076
# Test set: Accuracy: 72.14%  Loss: 0.7059
# TP: 396, FP: 129, TN: 210, FN: 105
# Sensitivity: 0.7904, Specificity: 0.6195, F1-Score: 0.7719
# ================================================================
# Train Epoch: 12 [3358/3358 (100.00%)]  Accuracy: 75.07%  Loss: 0.6906
# Test set: Accuracy: 71.90%  Loss: 0.7021
# TP: 372, FP: 107, TN: 232, FN: 129
# Sensitivity: 0.7425, Specificity: 0.6844, F1-Score: 0.7592
# ================================================================
# Train Epoch: 13 [3358/3358 (100.00%)]  Accuracy: 74.96%  Loss: 0.6903
# Test set: Accuracy: 72.62%  Loss: 0.7012
# TP: 377, FP: 106, TN: 233, FN: 124
# Sensitivity: 0.7525, Specificity: 0.6873, F1-Score: 0.7663
# ================================================================
# Train Epoch: 14 [3358/3358 (100.00%)]  Accuracy: 75.37%  Loss: 0.6896
# Test set: Accuracy: 73.33%  Loss: 0.6961
# TP: 380, FP: 103, TN: 236, FN: 121
# Sensitivity: 0.7585, Specificity: 0.6962, F1-Score: 0.7724
# ================================================================
# Train Epoch: 15 [3358/3358 (100.00%)]  Accuracy: 76.12%  Loss: 0.6844
# Test set: Accuracy: 72.38%  Loss: 0.7004
# TP: 390, FP: 121, TN: 218, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6431, F1-Score: 0.7708
# ================================================================
# Train Epoch: 16 [3358/3358 (100.00%)]  Accuracy: 77.07%  Loss: 0.6792
# Test set: Accuracy: 73.81%  Loss: 0.6959
# TP: 389, FP: 108, TN: 231, FN: 112
# Sensitivity: 0.7764, Specificity: 0.6814, F1-Score: 0.7796
# ================================================================
# Train Epoch: 17 [3358/3358 (100.00%)]  Accuracy: 78.14%  Loss: 0.6754
# Test set: Accuracy: 74.05%  Loss: 0.6928
# TP: 387, FP: 104, TN: 235, FN: 114
# Sensitivity: 0.7725, Specificity: 0.6932, F1-Score: 0.7802
# ================================================================
# Train Epoch: 18 [3358/3358 (100.00%)]  Accuracy: 77.96%  Loss: 0.6741
# Test set: Accuracy: 73.69%  Loss: 0.6939
# TP: 384, FP: 104, TN: 235, FN: 117
# Sensitivity: 0.7665, Specificity: 0.6932, F1-Score: 0.7765
# ================================================================
# Train Epoch: 19 [3358/3358 (100.00%)]  Accuracy: 79.09%  Loss: 0.6670
# Test set: Accuracy: 72.86%  Loss: 0.7010
# TP: 369, FP: 96, TN: 243, FN: 132
# Sensitivity: 0.7365, Specificity: 0.7168, F1-Score: 0.7640
# ================================================================
# Train Epoch: 20 [3358/3358 (100.00%)]  Accuracy: 79.93%  Loss: 0.6642
# Test set: Accuracy: 72.74%  Loss: 0.6972
# TP: 372, FP: 100, TN: 239, FN: 129
# Sensitivity: 0.7425, Specificity: 0.7050, F1-Score: 0.7646
# ================================================================
# Train Epoch: 21 [3358/3358 (100.00%)]  Accuracy: 79.30%  Loss: 0.6667
# Test set: Accuracy: 72.74%  Loss: 0.6966
# TP: 373, FP: 101, TN: 238, FN: 128
# Sensitivity: 0.7445, Specificity: 0.7021, F1-Score: 0.7651
# ================================================================
# Train Epoch: 22 [3358/3358 (100.00%)]  Accuracy: 79.66%  Loss: 0.6647
# Test set: Accuracy: 73.81%  Loss: 0.6946
# TP: 396, FP: 115, TN: 224, FN: 105
# Sensitivity: 0.7904, Specificity: 0.6608, F1-Score: 0.7826
# ================================================================
# Train Epoch: 23 [3358/3358 (100.00%)]  Accuracy: 80.70%  Loss: 0.6599
# Test set: Accuracy: 73.69%  Loss: 0.6943
# TP: 380, FP: 100, TN: 239, FN: 121
# Sensitivity: 0.7585, Specificity: 0.7050, F1-Score: 0.7747
# Epoch 00023: reducing learning rate of group 0 to 1.0000e-06.
# ================================================================
# Train Epoch: 24 [3358/3358 (100.00%)]  Accuracy: 80.02%  Loss: 0.6615
# Test set: Accuracy: 74.29%  Loss: 0.6906
# TP: 383, FP: 98, TN: 241, FN: 118
# Sensitivity: 0.7645, Specificity: 0.7109, F1-Score: 0.7800
# ================================================================
# Train Epoch: 25 [3358/3358 (100.00%)]  Accuracy: 80.94%  Loss: 0.6565
# Test set: Accuracy: 74.64%  Loss: 0.6928
# TP: 382, FP: 94, TN: 245, FN: 119
# Sensitivity: 0.7625, Specificity: 0.7227, F1-Score: 0.7820
# ================================================================
# Train Epoch: 26 [3358/3358 (100.00%)]  Accuracy: 81.63%  Loss: 0.6544
# Test set: Accuracy: 73.45%  Loss: 0.6956
# TP: 378, FP: 100, TN: 239, FN: 123
# Sensitivity: 0.7545, Specificity: 0.7050, F1-Score: 0.7722
# ================================================================
# Train Epoch: 27 [3358/3358 (100.00%)]  Accuracy: 82.25%  Loss: 0.6512
# Test set: Accuracy: 75.60%  Loss: 0.6862
# TP: 398, FP: 102, TN: 237, FN: 103
# Sensitivity: 0.7944, Specificity: 0.6991, F1-Score: 0.7952
# ================================================================
# Train Epoch: 28 [3358/3358 (100.00%)]  Accuracy: 81.95%  Loss: 0.6532
# Test set: Accuracy: 75.00%  Loss: 0.6887
# TP: 386, FP: 95, TN: 244, FN: 115
# Sensitivity: 0.7705, Specificity: 0.7198, F1-Score: 0.7862
# ================================================================
# Train Epoch: 29 [3358/3358 (100.00%)]  Accuracy: 82.76%  Loss: 0.6486
# Test set: Accuracy: 73.21%  Loss: 0.6963
# TP: 370, FP: 94, TN: 245, FN: 131
# Sensitivity: 0.7385, Specificity: 0.7227, F1-Score: 0.7668
# ================================================================
# Train Epoch: 30 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6509
# Test set: Accuracy: 73.93%  Loss: 0.6928
# TP: 386, FP: 104, TN: 235, FN: 115
# Sensitivity: 0.7705, Specificity: 0.6932, F1-Score: 0.7790
# ================================================================
# Train Epoch: 31 [3358/3358 (100.00%)]  Accuracy: 82.67%  Loss: 0.6482
# Test set: Accuracy: 73.10%  Loss: 0.6950
# TP: 383, FP: 108, TN: 231, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6814, F1-Score: 0.7722
# ================================================================
# Train Epoch: 32 [3358/3358 (100.00%)]  Accuracy: 82.28%  Loss: 0.6497
# Test set: Accuracy: 71.07%  Loss: 0.7058
# TP: 370, FP: 112, TN: 227, FN: 131
# Sensitivity: 0.7385, Specificity: 0.6696, F1-Score: 0.7528
# ================================================================
# Train Epoch: 33 [3358/3358 (100.00%)]  Accuracy: 82.04%  Loss: 0.6525
# Test set: Accuracy: 72.26%  Loss: 0.7001
# TP: 385, FP: 117, TN: 222, FN: 116
# Sensitivity: 0.7685, Specificity: 0.6549, F1-Score: 0.7677
# Epoch 00033: reducing learning rate of group 0 to 1.0000e-07.
# ================================================================
# Train Epoch: 34 [3358/3358 (100.00%)]  Accuracy: 82.10%  Loss: 0.6506
# Test set: Accuracy: 73.33%  Loss: 0.6921
# TP: 375, FP: 98, TN: 241, FN: 126
# Sensitivity: 0.7485, Specificity: 0.7109, F1-Score: 0.7700
# ================================================================
# Train Epoch: 35 [3358/3358 (100.00%)]  Accuracy: 82.64%  Loss: 0.6482
# Test set: Accuracy: 74.05%  Loss: 0.6917
# TP: 380, FP: 97, TN: 242, FN: 121
# Sensitivity: 0.7585, Specificity: 0.7139, F1-Score: 0.7771
# ================================================================
# Train Epoch: 36 [3358/3358 (100.00%)]  Accuracy: 82.37%  Loss: 0.6505
# Test set: Accuracy: 72.02%  Loss: 0.7024
# TP: 374, FP: 108, TN: 231, FN: 127
# Sensitivity: 0.7465, Specificity: 0.6814, F1-Score: 0.7609
# ================================================================
# Train Epoch: 37 [3358/3358 (100.00%)]  Accuracy: 81.60%  Loss: 0.6544
# Test set: Accuracy: 73.33%  Loss: 0.6977
# TP: 388, FP: 111, TN: 228, FN: 113
# Sensitivity: 0.7745, Specificity: 0.6726, F1-Score: 0.7760
# ================================================================
# Train Epoch: 38 [3358/3358 (100.00%)]  Accuracy: 81.92%  Loss: 0.6522
# Test set: Accuracy: 73.93%  Loss: 0.6916
# TP: 398, FP: 116, TN: 223, FN: 103
# Sensitivity: 0.7944, Specificity: 0.6578, F1-Score: 0.7842
# ================================================================
# Train Epoch: 39 [3358/3358 (100.00%)]  Accuracy: 82.22%  Loss: 0.6504
# Test set: Accuracy: 70.83%  Loss: 0.7048
# TP: 354, FP: 98, TN: 241, FN: 147
# Sensitivity: 0.7066, Specificity: 0.7109, F1-Score: 0.7429
# Epoch 00039: reducing learning rate of group 0 to 1.0000e-08.
# ================================================================
# Train Epoch: 40 [3358/3358 (100.00%)]  Accuracy: 81.86%  Loss: 0.6518
# Test set: Accuracy: 73.69%  Loss: 0.6954
# TP: 383, FP: 103, TN: 236, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6962, F1-Score: 0.7761
# ================================================================
# Train Epoch: 41 [3358/3358 (100.00%)]  Accuracy: 81.66%  Loss: 0.6533
# Test set: Accuracy: 73.57%  Loss: 0.6928
# TP: 366, FP: 87, TN: 252, FN: 135
# Sensitivity: 0.7305, Specificity: 0.7434, F1-Score: 0.7673
# ================================================================
# Train Epoch: 42 [3358/3358 (100.00%)]  Accuracy: 81.80%  Loss: 0.6528
# Test set: Accuracy: 72.98%  Loss: 0.6972
# TP: 358, FP: 84, TN: 255, FN: 143
# Sensitivity: 0.7146, Specificity: 0.7522, F1-Score: 0.7593
# ================================================================
# Train Epoch: 43 [3358/3358 (100.00%)]  Accuracy: 82.52%  Loss: 0.6481
# Test set: Accuracy: 73.10%  Loss: 0.6968
# TP: 387, FP: 112, TN: 227, FN: 114
# Sensitivity: 0.7725, Specificity: 0.6696, F1-Score: 0.7740
# ================================================================
# Train Epoch: 44 [3358/3358 (100.00%)]  Accuracy: 81.39%  Loss: 0.6543
# Test set: Accuracy: 73.45%  Loss: 0.6945
# TP: 371, FP: 93, TN: 246, FN: 130
# Sensitivity: 0.7405, Specificity: 0.7257, F1-Score: 0.7689
# ================================================================
# Train Epoch: 45 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6512
# Test set: Accuracy: 73.57%  Loss: 0.6945
# TP: 377, FP: 98, TN: 241, FN: 124
# Sensitivity: 0.7525, Specificity: 0.7109, F1-Score: 0.7725
# ================================================================
# Train Epoch: 46 [3358/3358 (100.00%)]  Accuracy: 82.19%  Loss: 0.6511
# Test set: Accuracy: 72.86%  Loss: 0.6954
# TP: 376, FP: 103, TN: 236, FN: 125
# Sensitivity: 0.7505, Specificity: 0.6962, F1-Score: 0.7673
# ================================================================
# Train Epoch: 47 [3358/3358 (100.00%)]  Accuracy: 82.19%  Loss: 0.6506
# Test set: Accuracy: 74.29%  Loss: 0.6903
# TP: 385, FP: 100, TN: 239, FN: 116
# Sensitivity: 0.7685, Specificity: 0.7050, F1-Score: 0.7809
# ================================================================
# Train Epoch: 48 [3358/3358 (100.00%)]  Accuracy: 82.25%  Loss: 0.6488
# Test set: Accuracy: 73.10%  Loss: 0.6955
# TP: 390, FP: 115, TN: 224, FN: 111
# Sensitivity: 0.7784, Specificity: 0.6608, F1-Score: 0.7753
# ================================================================
# Train Epoch: 49 [3358/3358 (100.00%)]  Accuracy: 82.76%  Loss: 0.6489
# Test set: Accuracy: 73.57%  Loss: 0.6954
# TP: 383, FP: 104, TN: 235, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6932, F1-Score: 0.7753
# ================================================================
# Train Epoch: 50 [3358/3358 (100.00%)]  Accuracy: 81.89%  Loss: 0.6527
# Test set: Accuracy: 74.29%  Loss: 0.6928
# TP: 382, FP: 97, TN: 242, FN: 119
# Sensitivity: 0.7625, Specificity: 0.7139, F1-Score: 0.7796
# ================================================================
# Train Epoch: 51 [3358/3358 (100.00%)]  Accuracy: 83.23%  Loss: 0.6468
# Test set: Accuracy: 73.21%  Loss: 0.6978
# TP: 375, FP: 99, TN: 240, FN: 126
# Sensitivity: 0.7485, Specificity: 0.7080, F1-Score: 0.7692
# ================================================================
# Train Epoch: 52 [3358/3358 (100.00%)]  Accuracy: 82.01%  Loss: 0.6505
# Test set: Accuracy: 74.29%  Loss: 0.6929
# TP: 392, FP: 107, TN: 232, FN: 109
# Sensitivity: 0.7824, Specificity: 0.6844, F1-Score: 0.7840
# ================================================================
# Train Epoch: 53 [3358/3358 (100.00%)]  Accuracy: 82.10%  Loss: 0.6512
# Test set: Accuracy: 72.62%  Loss: 0.6992
# TP: 362, FP: 91, TN: 248, FN: 139
# Sensitivity: 0.7226, Specificity: 0.7316, F1-Score: 0.7589
# ================================================================
# Train Epoch: 54 [3358/3358 (100.00%)]  Accuracy: 81.89%  Loss: 0.6521
# Test set: Accuracy: 73.69%  Loss: 0.6963
# TP: 375, FP: 95, TN: 244, FN: 126
# Sensitivity: 0.7485, Specificity: 0.7198, F1-Score: 0.7724
# ================================================================
# Train Epoch: 55 [3358/3358 (100.00%)]  Accuracy: 82.49%  Loss: 0.6483
# Test set: Accuracy: 75.00%  Loss: 0.6886
# TP: 384, FP: 93, TN: 246, FN: 117
# Sensitivity: 0.7665, Specificity: 0.7257, F1-Score: 0.7853
# ================================================================
# Train Epoch: 56 [3358/3358 (100.00%)]  Accuracy: 82.88%  Loss: 0.6473
# Test set: Accuracy: 74.29%  Loss: 0.6927
# TP: 391, FP: 106, TN: 233, FN: 110
# Sensitivity: 0.7804, Specificity: 0.6873, F1-Score: 0.7836
# ================================================================
# Train Epoch: 57 [3358/3358 (100.00%)]  Accuracy: 82.25%  Loss: 0.6498
# Test set: Accuracy: 74.88%  Loss: 0.6885
# TP: 394, FP: 104, TN: 235, FN: 107
# Sensitivity: 0.7864, Specificity: 0.6932, F1-Score: 0.7888
# ================================================================
# Train Epoch: 58 [3358/3358 (100.00%)]  Accuracy: 82.67%  Loss: 0.6486
# Test set: Accuracy: 74.05%  Loss: 0.6919
# TP: 392, FP: 109, TN: 230, FN: 109
# Sensitivity: 0.7824, Specificity: 0.6785, F1-Score: 0.7824
# ================================================================
# Train Epoch: 59 [3358/3358 (100.00%)]  Accuracy: 82.58%  Loss: 0.6486
# Test set: Accuracy: 73.57%  Loss: 0.6953
# TP: 399, FP: 120, TN: 219, FN: 102
# Sensitivity: 0.7964, Specificity: 0.6460, F1-Score: 0.7824
# ================================================================
# Train Epoch: 60 [3358/3358 (100.00%)]  Accuracy: 81.51%  Loss: 0.6536
# Test set: Accuracy: 74.76%  Loss: 0.6886
# TP: 391, FP: 102, TN: 237, FN: 110
# Sensitivity: 0.7804, Specificity: 0.6991, F1-Score: 0.7867
# ================================================================
# Train Epoch: 61 [3358/3358 (100.00%)]  Accuracy: 82.22%  Loss: 0.6505
# Test set: Accuracy: 74.05%  Loss: 0.6923
# TP: 372, FP: 89, TN: 250, FN: 129
# Sensitivity: 0.7425, Specificity: 0.7375, F1-Score: 0.7734
# ================================================================
# Train Epoch: 62 [3358/3358 (100.00%)]  Accuracy: 82.73%  Loss: 0.6471
# Test set: Accuracy: 75.12%  Loss: 0.6908
# TP: 407, FP: 115, TN: 224, FN: 94
# Sensitivity: 0.8124, Specificity: 0.6608, F1-Score: 0.7957
# ================================================================
# Train Epoch: 63 [3358/3358 (100.00%)]  Accuracy: 82.04%  Loss: 0.6511
# Test set: Accuracy: 73.57%  Loss: 0.6959
# TP: 389, FP: 110, TN: 229, FN: 112
# Sensitivity: 0.7764, Specificity: 0.6755, F1-Score: 0.7780
# ================================================================
# Train Epoch: 64 [3358/3358 (100.00%)]  Accuracy: 81.86%  Loss: 0.6524
# Test set: Accuracy: 71.67%  Loss: 0.7010
# TP: 368, FP: 105, TN: 234, FN: 133
# Sensitivity: 0.7345, Specificity: 0.6903, F1-Score: 0.7556
# ================================================================
# Train Epoch: 65 [3358/3358 (100.00%)]  Accuracy: 82.73%  Loss: 0.6486
# Test set: Accuracy: 73.69%  Loss: 0.6934
# TP: 379, FP: 99, TN: 240, FN: 122
# Sensitivity: 0.7565, Specificity: 0.7080, F1-Score: 0.7743
# ================================================================
# Train Epoch: 66 [3358/3358 (100.00%)]  Accuracy: 81.98%  Loss: 0.6511
# Test set: Accuracy: 73.33%  Loss: 0.6963
# TP: 367, FP: 90, TN: 249, FN: 134
# Sensitivity: 0.7325, Specificity: 0.7345, F1-Score: 0.7662
# ================================================================
# Train Epoch: 67 [3358/3358 (100.00%)]  Accuracy: 81.39%  Loss: 0.6549
# Test set: Accuracy: 72.62%  Loss: 0.6993
# TP: 383, FP: 112, TN: 227, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6696, F1-Score: 0.7691
# ================================================================
# Train Epoch: 68 [3358/3358 (100.00%)]  Accuracy: 82.85%  Loss: 0.6474
# Test set: Accuracy: 73.10%  Loss: 0.6970
# TP: 368, FP: 93, TN: 246, FN: 133
# Sensitivity: 0.7345, Specificity: 0.7257, F1-Score: 0.7651
# ================================================================
# Train Epoch: 69 [3358/3358 (100.00%)]  Accuracy: 82.01%  Loss: 0.6509
# Test set: Accuracy: 74.88%  Loss: 0.6881
# TP: 377, FP: 87, TN: 252, FN: 124
# Sensitivity: 0.7525, Specificity: 0.7434, F1-Score: 0.7813
# ================================================================
# Train Epoch: 70 [3358/3358 (100.00%)]  Accuracy: 82.52%  Loss: 0.6497
# Test set: Accuracy: 73.45%  Loss: 0.6946
# TP: 367, FP: 89, TN: 250, FN: 134
# Sensitivity: 0.7325, Specificity: 0.7375, F1-Score: 0.7670
# ================================================================
# Train Epoch: 71 [3358/3358 (100.00%)]  Accuracy: 82.94%  Loss: 0.6481
# Test set: Accuracy: 73.10%  Loss: 0.6949
# TP: 378, FP: 103, TN: 236, FN: 123
# Sensitivity: 0.7545, Specificity: 0.6962, F1-Score: 0.7699
# ================================================================
# Train Epoch: 72 [3358/3358 (100.00%)]  Accuracy: 82.97%  Loss: 0.6465
# Test set: Accuracy: 72.86%  Loss: 0.6974
# TP: 372, FP: 99, TN: 240, FN: 129
# Sensitivity: 0.7425, Specificity: 0.7080, F1-Score: 0.7654
# ================================================================
# Train Epoch: 73 [3358/3358 (100.00%)]  Accuracy: 82.10%  Loss: 0.6515
# Test set: Accuracy: 74.40%  Loss: 0.6916
# TP: 381, FP: 95, TN: 244, FN: 120
# Sensitivity: 0.7605, Specificity: 0.7198, F1-Score: 0.7799
# ================================================================
# Train Epoch: 74 [3358/3358 (100.00%)]  Accuracy: 81.60%  Loss: 0.6545
# Test set: Accuracy: 73.81%  Loss: 0.6936
# TP: 383, FP: 102, TN: 237, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6991, F1-Score: 0.7769
# ================================================================
# Train Epoch: 75 [3358/3358 (100.00%)]  Accuracy: 81.45%  Loss: 0.6541
# Test set: Accuracy: 71.55%  Loss: 0.7001
# TP: 367, FP: 105, TN: 234, FN: 134
# Sensitivity: 0.7325, Specificity: 0.6903, F1-Score: 0.7544
# ================================================================
# Train Epoch: 76 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6499
# Test set: Accuracy: 73.81%  Loss: 0.6962
# TP: 389, FP: 108, TN: 231, FN: 112
# Sensitivity: 0.7764, Specificity: 0.6814, F1-Score: 0.7796
# ================================================================
# Train Epoch: 77 [3358/3358 (100.00%)]  Accuracy: 82.67%  Loss: 0.6478
# Test set: Accuracy: 73.10%  Loss: 0.6984
# TP: 369, FP: 94, TN: 245, FN: 132
# Sensitivity: 0.7365, Specificity: 0.7227, F1-Score: 0.7656
# ================================================================
# Train Epoch: 78 [3358/3358 (100.00%)]  Accuracy: 81.89%  Loss: 0.6519
# Test set: Accuracy: 73.45%  Loss: 0.6965
# TP: 385, FP: 107, TN: 232, FN: 116
# Sensitivity: 0.7685, Specificity: 0.6844, F1-Score: 0.7754
# ================================================================
# Train Epoch: 79 [3358/3358 (100.00%)]  Accuracy: 82.01%  Loss: 0.6506
# Test set: Accuracy: 72.62%  Loss: 0.6984
# TP: 377, FP: 106, TN: 233, FN: 124
# Sensitivity: 0.7525, Specificity: 0.6873, F1-Score: 0.7663
# ================================================================
# Train Epoch: 80 [3358/3358 (100.00%)]  Accuracy: 82.64%  Loss: 0.6490
# Test set: Accuracy: 73.45%  Loss: 0.6948
# TP: 376, FP: 98, TN: 241, FN: 125
# Sensitivity: 0.7505, Specificity: 0.7109, F1-Score: 0.7713
# ================================================================
# Train Epoch: 81 [3358/3358 (100.00%)]  Accuracy: 82.37%  Loss: 0.6495
# Test set: Accuracy: 72.98%  Loss: 0.6964
# TP: 364, FP: 90, TN: 249, FN: 137
# Sensitivity: 0.7265, Specificity: 0.7345, F1-Score: 0.7623
# ================================================================
# Train Epoch: 82 [3358/3358 (100.00%)]  Accuracy: 82.43%  Loss: 0.6500
# Test set: Accuracy: 73.93%  Loss: 0.6914
# TP: 382, FP: 100, TN: 239, FN: 119
# Sensitivity: 0.7625, Specificity: 0.7050, F1-Score: 0.7772
# ================================================================
# Train Epoch: 83 [3358/3358 (100.00%)]  Accuracy: 82.10%  Loss: 0.6514
# Test set: Accuracy: 72.74%  Loss: 0.6987
# TP: 366, FP: 94, TN: 245, FN: 135
# Sensitivity: 0.7305, Specificity: 0.7227, F1-Score: 0.7617
# ================================================================
# Train Epoch: 84 [3358/3358 (100.00%)]  Accuracy: 82.43%  Loss: 0.6504
# Test set: Accuracy: 72.50%  Loss: 0.6992
# TP: 368, FP: 98, TN: 241, FN: 133
# Sensitivity: 0.7345, Specificity: 0.7109, F1-Score: 0.7611
# ================================================================
# Train Epoch: 85 [3358/3358 (100.00%)]  Accuracy: 82.04%  Loss: 0.6497
# Test set: Accuracy: 74.52%  Loss: 0.6900
# TP: 388, FP: 101, TN: 238, FN: 113
# Sensitivity: 0.7745, Specificity: 0.7021, F1-Score: 0.7838
# ================================================================
# Train Epoch: 86 [3358/3358 (100.00%)]  Accuracy: 82.40%  Loss: 0.6498
# Test set: Accuracy: 73.33%  Loss: 0.6958
# TP: 372, FP: 95, TN: 244, FN: 129
# Sensitivity: 0.7425, Specificity: 0.7198, F1-Score: 0.7686
# ================================================================
# Train Epoch: 87 [3358/3358 (100.00%)]  Accuracy: 82.43%  Loss: 0.6492
# Test set: Accuracy: 72.86%  Loss: 0.6958
# TP: 373, FP: 100, TN: 239, FN: 128
# Sensitivity: 0.7445, Specificity: 0.7050, F1-Score: 0.7659
# ================================================================
# Train Epoch: 88 [3358/3358 (100.00%)]  Accuracy: 82.28%  Loss: 0.6503
# Test set: Accuracy: 73.21%  Loss: 0.6935
# TP: 383, FP: 107, TN: 232, FN: 118
# Sensitivity: 0.7645, Specificity: 0.6844, F1-Score: 0.7730
# ================================================================
# Train Epoch: 89 [3358/3358 (100.00%)]  Accuracy: 82.10%  Loss: 0.6506
# Test set: Accuracy: 73.33%  Loss: 0.6938
# TP: 374, FP: 97, TN: 242, FN: 127
# Sensitivity: 0.7465, Specificity: 0.7139, F1-Score: 0.7695
# ================================================================
# Train Epoch: 90 [3358/3358 (100.00%)]  Accuracy: 83.00%  Loss: 0.6471
# Test set: Accuracy: 74.52%  Loss: 0.6912
# TP: 401, FP: 114, TN: 225, FN: 100
# Sensitivity: 0.8004, Specificity: 0.6637, F1-Score: 0.7894
# ================================================================
# Train Epoch: 91 [3358/3358 (100.00%)]  Accuracy: 82.10%  Loss: 0.6505
# Test set: Accuracy: 73.69%  Loss: 0.6946
# TP: 378, FP: 98, TN: 241, FN: 123
# Sensitivity: 0.7545, Specificity: 0.7109, F1-Score: 0.7738
# ================================================================
# Train Epoch: 92 [3358/3358 (100.00%)]  Accuracy: 81.75%  Loss: 0.6525
# Test set: Accuracy: 73.81%  Loss: 0.6958
# TP: 387, FP: 106, TN: 233, FN: 114
# Sensitivity: 0.7725, Specificity: 0.6873, F1-Score: 0.7787
# ================================================================
# Train Epoch: 93 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6508
# Test set: Accuracy: 72.74%  Loss: 0.7005
# TP: 369, FP: 97, TN: 242, FN: 132
# Sensitivity: 0.7365, Specificity: 0.7139, F1-Score: 0.7632
# ================================================================
# Train Epoch: 94 [3358/3358 (100.00%)]  Accuracy: 82.31%  Loss: 0.6509
# Test set: Accuracy: 74.17%  Loss: 0.6929
# TP: 382, FP: 98, TN: 241, FN: 119
# Sensitivity: 0.7625, Specificity: 0.7109, F1-Score: 0.7788
# ================================================================
# Train Epoch: 95 [3358/3358 (100.00%)]  Accuracy: 82.01%  Loss: 0.6517
# Test set: Accuracy: 73.33%  Loss: 0.6957
# TP: 385, FP: 108, TN: 231, FN: 116
# Sensitivity: 0.7685, Specificity: 0.6814, F1-Score: 0.7746
# ================================================================
# Train Epoch: 96 [3358/3358 (100.00%)]  Accuracy: 82.70%  Loss: 0.6490
# Test set: Accuracy: 75.24%  Loss: 0.6861
# TP: 399, FP: 106, TN: 233, FN: 102
# Sensitivity: 0.7964, Specificity: 0.6873, F1-Score: 0.7932
# ================================================================
# Train Epoch: 97 [3358/3358 (100.00%)]  Accuracy: 82.31%  Loss: 0.6511
# Test set: Accuracy: 72.86%  Loss: 0.6979
# TP: 367, FP: 94, TN: 245, FN: 134
# Sensitivity: 0.7325, Specificity: 0.7227, F1-Score: 0.7630
# ================================================================
# Train Epoch: 98 [3358/3358 (100.00%)]  Accuracy: 82.34%  Loss: 0.6505
# Test set: Accuracy: 73.93%  Loss: 0.6903
# TP: 367, FP: 85, TN: 254, FN: 134
# Sensitivity: 0.7325, Specificity: 0.7493, F1-Score: 0.7702
# ================================================================
# Train Epoch: 99 [3358/3358 (100.00%)]  Accuracy: 81.92%  Loss: 0.6505
# Test set: Accuracy: 74.17%  Loss: 0.6925
# TP: 387, FP: 103, TN: 236, FN: 114
# Sensitivity: 0.7725, Specificity: 0.6962, F1-Score: 0.7810
# ================================================================
# Train Epoch: 100 [3358/3358 (100.00%)]  Accuracy: 81.98%  Loss: 0.6521
# Test set: Accuracy: 73.10%  Loss: 0.6967
# TP: 378, FP: 103, TN: 236, FN: 123
# Sensitivity: 0.7545, Specificity: 0.6962, F1-Score: 0.7699
# ================================================================

# %%
accs_np = np.array(accs)
losses_np = np.array(losses)
np.save('./orig_t_mix_acc_.npy', accs_np)
np.save('./orig_t_mix_loss_.npy', losses_np)

torch.save(best_acc_model, './orig_t_best_acc_model_.pt')
torch.save(best_acc_model_state, './orig_t_best_acc_model_state_.pt')
torch.save(best_f1_model, './orig_t_best_f1_model_.pt')
torch.save(best_f1_model_state, './orig_t_best_f1_model_state_.pt')
