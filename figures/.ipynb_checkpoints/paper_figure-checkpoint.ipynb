# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
x1 = Image.open('D:/Doby/OMS/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p12/p12001854/s52513801/de99ab7b-14208cb1-78f4f471-ecfc501e-bd213bee.jpg')
plt.subplot(1, 2, 1)
plt.imshow(x1, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel('Frontal view (a)', fontsize=18)

x2 = Image.open('D:/Doby/OMS/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p12/p12001854/s52513801/e62f7299-2695b062-38ab6561-0f9891ae-7b07a308.jpg')
plt.subplot(1, 2, 2)
plt.imshow(x2, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.xlabel('Lateral view (b)', fontsize=18)

plt.savefig('./figure1.jpg', dpi=500, pad_inches=0)
