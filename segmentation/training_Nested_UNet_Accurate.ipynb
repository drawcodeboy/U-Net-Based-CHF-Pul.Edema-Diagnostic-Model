# %%
import torch
from torch import nn
from torchvision import transforms
from torchvision import models
from torchvision.transforms.functional import to_pil_image
import matplotlib.pyplot as plt
from monai.losses import DiceLoss
from PIL import Image
from PIL import ImageFilter
from PIL import ImageOps
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
from copy import copy
from copy import deepcopy
import cv2
import sys
import os
import pandas as pd
import numpy as np
import random
from pathlib import Path
import math
from Nested_UNet import Nested_UNet
# from evaluation import *

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True' # dead kernel for matplotlib

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
metadata = pd.read_csv('../doby_meta.csv')
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7064 entries, 0 to 7063
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      7064 non-null   int64
#  1   study_id        7064 non-null   int64
#  2   dicom_id        7064 non-null   object
#  3   DicomPath       7064 non-null   object
#  4   edema_severity  7064 non-null   int64
#  5   normal          7064 non-null   int64
#  6   CHF             7064 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 338.2+ KB

# %%
metadata = metadata[metadata['subject_id'] < 16000000]
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4198 entries, 0 to 4197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      4198 non-null   int64
#  1   study_id        4198 non-null   int64
#  2   dicom_id        4198 non-null   object
#  3   DicomPath       4198 non-null   object
#  4   edema_severity  4198 non-null   int64
#  5   normal          4198 non-null   int64
#  6   CHF             4198 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 233.7+ KB

# %%
SEG_BASE_PATH = '../chest-x-ray-dataset-with-lung-segmentation-1.0.0/chest-x-ray-dataset-with-lung-segmentation-1.0.0'
ORIG_BASE_PATH = '../physionet.org/files/mimic-cxr-jpg/2.0.0'

# %%
TRAIN_TRANSFORMS = transforms.Compose([
    transforms.ToTensor()
])

TARGET_TRANSFORMS = transforms.Compose([
    transforms.ToTensor()
])

# %%
class Dataset(Dataset):
    def __init__(self, metadata, mask_base_path, orig_base_path, transform=None, target_transform=None):
        self.metadata = metadata
        self.base_path = Path(orig_base_path)
        self.mask_path = Path(mask_base_path)
        
        self.transform = transform
        self.target_transform = target_transform
        
    def __getitem__(self, idx):
        detail_path = self.metadata.loc[idx, 'DicomPath']
        y_path = self.mask_path / Path(str(detail_path[:-4]) + '-mask.jpg')
        x_path = self.base_path / Path(str(detail_path))

        y = Image.open(str(y_path))
        x = cv2.imread(str(x_path), cv2.IMREAD_GRAYSCALE)
        x = cv2.resize(x, dsize=(224, 224), interpolation=cv2.INTER_AREA)

        del detail_path
        del y_path
        del x_path

        # 이것 때문인지는 모르겠는데 ToTensor로 Normalize가 안 된다.
        # y = np.where(y > 128, 255, 0) # 128 threshold
        # y = np.where(y > 128, 255, 0) / 255.
        
        if self.transform:
            x = self.transform(x)

        if self.target_transform:
            y = self.target_transform(y)

        return x, y

    def __len__(self):
        return self.metadata['normal'].count()

# %%
ds = Dataset(metadata, 
             SEG_BASE_PATH, 
             ORIG_BASE_PATH,
             transform=TRAIN_TRANSFORMS,
             target_transform=TARGET_TRANSFORMS)

# %%
ds_size = len(ds)
train_size = int(ds_size * 0.8)
test_size = ds_size - train_size
train_ds, test_ds = random_split(ds, [train_size, test_size], generator=torch.manual_seed(42))

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True)
test_dl = DataLoader(test_ds, batch_size=8, shuffle=True)

# %%
model = Nested_UNet(channel=1, mode='accurate') # feature size 10%
model.to(device)
# Out:
# Nested_UNet(
#   (x_0_0): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (x_1_0): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (x_2_0): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (x_3_0): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (x_4_0): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (x_0_1): DecoderBlock(
#     (transposeConv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_1_1): DecoderBlock(
#     (transposeConv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_2_1): DecoderBlock(
#     (transposeConv): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_3_1): DecoderBlock(
#     (transposeConv): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_0_2): DecoderBlock(
#     (transposeConv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_1_2): DecoderBlock(
#     (transposeConv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_2_2): DecoderBlock(
#     (transposeConv): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_0_3): DecoderBlock(
#     (transposeConv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_1_3): DecoderBlock(
#     (transposeConv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (x_0_4): DecoderBlock(
#     (transposeConv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(160, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (convOut): ModuleList(
#     (0-3): 4 x Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (acti): Sigmoid()
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
schedular = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
loss_fn = DiceLoss(reduction='mean').to(device)

# %%
def train(model, data_loader, optimizer, epoch):
    model.train()
    running_loss = 0
    running_acc = 0
    n_data = 0

    for batch_idx, (batch, target) in enumerate(data_loader, start=1):
        batch, target = batch.to(device), target.to(device)

        optimizer.zero_grad()

        output = model(batch)
        output_flat = output.view(output.size(0), -1)
        target_flat = target.view(target.size(0), -1)

        loss = loss_fn(output_flat, target_flat)
        running_loss += loss.item()

        output_flat = (output_flat >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)
        correct = (output_flat == target_flat).sum().item()
        running_acc += correct

        loss.backward()
        optimizer.step()

        # Pixel 별 Accuracy
        n_data += len(batch)
        output_pixels = (output_flat.shape[1])
        
        print(f'\rTrain Epoch: {epoch} [{n_data}/{len(data_loader.dataset)} ({100 * batch_idx / len(data_loader):.2f}%)]  Accuracy: {100*running_acc/(n_data*output_pixels):.2f}%  Loss: {running_loss/batch_idx:.4f}', end='')

# %%
def test(model, data_loader):
    model.eval()
    test_acc = 0
    test_loss = 0
    n_data = 0
    TP, FP, TN, FN = 0, 0, 0, 0
    output_pixels = 0
    
    with torch.no_grad():
        for batch, target in data_loader:
            batch, target = batch.to(device), target.to(device)

            output = model(batch)

            output_flat = output.view(output.size(0), -1)
            target_flat = target.view(target.size(0), -1)

            loss = loss_fn(output_flat, target_flat)
            test_loss += loss.item()

            output_flat = (output_flat >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)

            correct = (output_flat == target_flat).sum().item()
            test_acc += correct

            TP += ((output_flat == target_flat) & (target_flat == 1)).sum().item()
            FP += ((output_flat != target_flat) & (target_flat == 0)).sum().item()
            TN += ((output_flat == target_flat) & (target_flat == 0)).sum().item()
            FN += ((output_flat != target_flat) & (target_flat == 1)).sum().item()
            
            n_data += len(batch)
            output_pixels = (output_flat.shape[1])
            
            print(f'\rTest set: [{100*n_data/len(data_loader.dataset):.2f}%]', end='')
    
    test_acc = 100 * test_acc / (len(data_loader.dataset)*output_pixels)
    test_loss = test_loss / len(data_loader)
    
    print(f'\rTest set: Accuracy: {test_acc:.2f}%  Loss: {test_loss:.4f}')

    return test_acc, test_loss, TP, FP, TN, FN

# %%
def getMetric(TP, FP, TN, FN):
    # base case: divide by zero
    TP = 0.1 if TP == 0 else TP
    FP = 0.1 if FP == 0 else FP
    TN = 0.1 if TN == 0 else TN
    FN = 0.1 if FN == 0 else FN
    
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    f1_score = 2*precision*recall/(precision+recall)
    mcc = ((TP*TN)-(FP*FN))/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    
    return sensitivity, specificity, f1_score, mcc

# %%
accs = []
losses = []
best_acc = 0
best_f1 = 0

best_acc_model = None
best_acc_model_state = None
best_f1_model = None
best_f1_model_state = None

# %%
for epoch in range(1, 50+1):
    train(model, train_dl, optimizer, epoch)
    
    print()
    
    acc, loss, tp, fp, tn, fn = test(model, test_dl)
    sensitivity, specificity, f1_score, mcc = getMetric(tp, fp, tn, fn)
    print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')
    print(f'Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}\nF1-Score: {f1_score:.4f}, MCC: {mcc:.4f}')

    if acc > best_acc:
        best_acc = acc
        best_acc_model = deepcopy(model)
        best_acc_model_state = deepcopy(model.state_dict())

    if f1_score > best_f1:
        best_f1 = f1_score
        best_f1_model = deepcopy(model)
        best_f1_model_state = deepcopy(model.state_dict())
        
    schedular.step(loss)
    accs.append(acc)
    losses.append(loss)

    print('================================================================')
# Out:
# Train Epoch: 1 [3358/3358 (100.00%)]  Accuracy: 86.48%  Loss: 0.2004
# Test set: Accuracy: 93.35%  Loss: 0.0651
# TP: 11344093, FP: 544125, TN: 27999081, FN: 467446
# Sensitivity: 0.9604, Specificity: 0.9809
# F1-Score: 0.9573, MCC: 0.9396
# ================================================================
# Train Epoch: 2 [3358/3358 (100.00%)]  Accuracy: 93.82%  Loss: 0.0520
# Test set: Accuracy: 93.40%  Loss: 0.0573
# TP: 11300180, FP: 478138, TN: 28065068, FN: 511359
# Sensitivity: 0.9567, Specificity: 0.9832
# F1-Score: 0.9581, MCC: 0.9407
# ================================================================
# Train Epoch: 3 [3358/3358 (100.00%)]  Accuracy: 94.07%  Loss: 0.0423
# Test set: Accuracy: 93.67%  Loss: 0.0460
# TP: 11535477, FP: 599830, TN: 27943376, FN: 276062
# Sensitivity: 0.9766, Specificity: 0.9790
# F1-Score: 0.9634, MCC: 0.9482
# ================================================================
# Train Epoch: 4 [3358/3358 (100.00%)]  Accuracy: 94.28%  Loss: 0.0363
# Test set: Accuracy: 94.03%  Loss: 0.0397
# TP: 11347407, FP: 257478, TN: 28285728, FN: 464132
# Sensitivity: 0.9607, Specificity: 0.9910
# F1-Score: 0.9692, MCC: 0.9567
# ================================================================
# Train Epoch: 5 [3358/3358 (100.00%)]  Accuracy: 94.40%  Loss: 0.0333
# Test set: Accuracy: 94.17%  Loss: 0.0362
# TP: 11483525, FP: 335965, TN: 28207241, FN: 328014
# Sensitivity: 0.9722, Specificity: 0.9882
# F1-Score: 0.9719, MCC: 0.9603
# ================================================================
# Train Epoch: 6 [3358/3358 (100.00%)]  Accuracy: 94.50%  Loss: 0.0307
# Test set: Accuracy: 94.34%  Loss: 0.0329
# TP: 11546406, FP: 248401, TN: 28294805, FN: 265133
# Sensitivity: 0.9776, Specificity: 0.9913
# F1-Score: 0.9782, MCC: 0.9693
# ================================================================
# Train Epoch: 25 [3358/3358 (100.00%)]  Accuracy: 95.25%  Loss: 0.0138
# Test set: Accuracy: 94.50%  Loss: 0.0280
# TP: 11594042, FP: 306858, TN: 28236348, FN: 217497
# Sensitivity: 0.9816, Specificity: 0.9892
# F1-Score: 0.9779, MCC: 0.9687
# ================================================================
# Train Epoch: 26 [3358/3358 (100.00%)]  Accuracy: 95.26%  Loss: 0.0136
# Test set: Accuracy: 94.47%  Loss: 0.0282
# TP: 11582053, FP: 307045, TN: 28236161, FN: 229486
# Sensitivity: 0.9806, Specificity: 0.9892
# F1-Score: 0.9774, MCC: 0.9680
# ================================================================
# Train Epoch: 27 [3358/3358 (100.00%)]  Accuracy: 95.27%  Loss: 0.0132
# Test set: Accuracy: 94.53%  Loss: 0.0274
# TP: 11537494, FP: 238174, TN: 28305032, FN: 274045
# Sensitivity: 0.9768, Specificity: 0.9917
# F1-Score: 0.9783, MCC: 0.9693
# ================================================================
# Train Epoch: 28 [3358/3358 (100.00%)]  Accuracy: 95.26%  Loss: 0.0135
# Test set: Accuracy: 94.50%  Loss: 0.0281
# TP: 11504992, FP: 219821, TN: 28323385, FN: 306547
# Sensitivity: 0.9740, Specificity: 0.9923
# F1-Score: 0.9776, MCC: 0.9684
# ================================================================
# Train Epoch: 29 [3358/3358 (100.00%)]  Accuracy: 95.30%  Loss: 0.0127
# Test set: Accuracy: 94.52%  Loss: 0.0274
# TP: 11561476, FP: 265647, TN: 28277559, FN: 250063
# Sensitivity: 0.9788, Specificity: 0.9907
# F1-Score: 0.9782, MCC: 0.9691
# ================================================================
# Train Epoch: 30 [3358/3358 (100.00%)]  Accuracy: 95.31%  Loss: 0.0124
# Test set: Accuracy: 94.53%  Loss: 0.0274
# TP: 11537052, FP: 239511, TN: 28303695, FN: 274487
# Sensitivity: 0.9768, Specificity: 0.9916
# F1-Score: 0.9782, MCC: 0.9692
# ================================================================
# Train Epoch: 31 [3358/3358 (100.00%)]  Accuracy: 95.33%  Loss: 0.0119
# Test set: Accuracy: 94.53%  Loss: 0.0273
# TP: 11526263, FP: 225451, TN: 28317755, FN: 285276
# Sensitivity: 0.9758, Specificity: 0.9921
# F1-Score: 0.9783, MCC: 0.9694
# ================================================================
# Train Epoch: 32 [3358/3358 (100.00%)]  Accuracy: 95.33%  Loss: 0.0118
# Test set: Accuracy: 94.50%  Loss: 0.0277
# TP: 11508794, FP: 220719, TN: 28322487, FN: 302745
# Sensitivity: 0.9744, Specificity: 0.9923
# F1-Score: 0.9778, MCC: 0.9686
# ================================================================
# Train Epoch: 33 [3358/3358 (100.00%)]  Accuracy: 95.34%  Loss: 0.0118
# Test set: Accuracy: 94.56%  Loss: 0.0267
# TP: 11522720, FP: 210321, TN: 28332885, FN: 288819
# Sensitivity: 0.9755, Specificity: 0.9926
# F1-Score: 0.9788, MCC: 0.9701
# ================================================================
# Train Epoch: 34 [3358/3358 (100.00%)]  Accuracy: 95.35%  Loss: 0.0113
# Test set: Accuracy: 94.52%  Loss: 0.0272
# TP: 11550950, FP: 254398, TN: 28288808, FN: 260589
# Sensitivity: 0.9779, Specificity: 0.9911
# F1-Score: 0.9782, MCC: 0.9692
# ================================================================
# Train Epoch: 35 [3358/3358 (100.00%)]  Accuracy: 95.36%  Loss: 0.0113
# Test set: Accuracy: 94.55%  Loss: 0.0268
# TP: 11557072, FP: 249316, TN: 28293890, FN: 254467
# Sensitivity: 0.9785, Specificity: 0.9913
# F1-Score: 0.9787, MCC: 0.9698
# ================================================================
# Train Epoch: 36 [3358/3358 (100.00%)]  Accuracy: 95.36%  Loss: 0.0112
# Test set: Accuracy: 94.50%  Loss: 0.0280
# TP: 11517452, FP: 232702, TN: 28310504, FN: 294087
# Sensitivity: 0.9751, Specificity: 0.9918
# F1-Score: 0.9776, MCC: 0.9684
# ================================================================
# Train Epoch: 37 [3358/3358 (100.00%)]  Accuracy: 95.37%  Loss: 0.0110
# Test set: Accuracy: 94.49%  Loss: 0.0282
# TP: 11555624, FP: 274624, TN: 28268582, FN: 255915
# Sensitivity: 0.9783, Specificity: 0.9904
# F1-Score: 0.9776, MCC: 0.9683
# ================================================================
# Train Epoch: 38 [3358/3358 (100.00%)]  Accuracy: 95.37%  Loss: 0.0109
# Test set: Accuracy: 94.49%  Loss: 0.0282
# TP: 11512243, FP: 229500, TN: 28313706, FN: 299296
# Sensitivity: 0.9747, Specificity: 0.9920
# F1-Score: 0.9775, MCC: 0.9683
# ================================================================
# Train Epoch: 39 [3358/3358 (100.00%)]  Accuracy: 95.38%  Loss: 0.0107
# Test set: Accuracy: 94.53%  Loss: 0.0272
# TP: 11503411, FP: 204436, TN: 28338770, FN: 308128
# Sensitivity: 0.9739, Specificity: 0.9928
# F1-Score: 0.9782, MCC: 0.9693
# Epoch 00039: reducing learning rate of group 0 to 1.0000e-05.
# ================================================================
# Train Epoch: 40 [3358/3358 (100.00%)]  Accuracy: 95.45%  Loss: 0.0091
# Test set: Accuracy: 94.59%  Loss: 0.0261
# TP: 11536947, FP: 213177, TN: 28330029, FN: 274592
# Sensitivity: 0.9768, Specificity: 0.9925
# F1-Score: 0.9793, MCC: 0.9708
# ================================================================
# Train Epoch: 41 [3358/3358 (100.00%)]  Accuracy: 95.48%  Loss: 0.0083
# Test set: Accuracy: 94.59%  Loss: 0.0260
# TP: 11535758, FP: 211465, TN: 28331741, FN: 275781
# Sensitivity: 0.9767, Specificity: 0.9926
# F1-Score: 0.9793, MCC: 0.9708
# ================================================================
# Train Epoch: 42 [3358/3358 (100.00%)]  Accuracy: 95.50%  Loss: 0.0079
# Test set: Accuracy: 94.59%  Loss: 0.0260
# TP: 11533108, FP: 208550, TN: 28334656, FN: 278431
# Sensitivity: 0.9764, Specificity: 0.9927
# F1-Score: 0.9793, MCC: 0.9708
# ================================================================
# Train Epoch: 43 [3358/3358 (100.00%)]  Accuracy: 95.51%  Loss: 0.0077
# Test set: Accuracy: 94.59%  Loss: 0.0261
# TP: 11528503, FP: 204562, TN: 28338644, FN: 283036
# Sensitivity: 0.9760, Specificity: 0.9928
# F1-Score: 0.9793, MCC: 0.9708
# ================================================================
# Train Epoch: 44 [3358/3358 (100.00%)]  Accuracy: 95.52%  Loss: 0.0074
# Test set: Accuracy: 94.59%  Loss: 0.0262
# TP: 11530315, FP: 206927, TN: 28336279, FN: 281224
# Sensitivity: 0.9762, Specificity: 0.9928
# F1-Score: 0.9793, MCC: 0.9707
# ================================================================
# Train Epoch: 45 [3358/3358 (100.00%)]  Accuracy: 95.53%  Loss: 0.0073
# Test set: Accuracy: 94.59%  Loss: 0.0261
# TP: 11524975, FP: 201485, TN: 28341721, FN: 286564
# Sensitivity: 0.9757, Specificity: 0.9929
# F1-Score: 0.9793, MCC: 0.9707
# ================================================================
# Train Epoch: 46 [3358/3358 (100.00%)]  Accuracy: 95.53%  Loss: 0.0071
# Test set: Accuracy: 94.59%  Loss: 0.0261
# TP: 11519594, FP: 197158, TN: 28346048, FN: 291945
# Sensitivity: 0.9753, Specificity: 0.9931
# F1-Score: 0.9792, MCC: 0.9707
# ================================================================
# Train Epoch: 47 [3358/3358 (100.00%)]  Accuracy: 95.54%  Loss: 0.0070
# Test set: Accuracy: 94.59%  Loss: 0.0260
# TP: 11532582, FP: 209860, TN: 28333346, FN: 278957
# Sensitivity: 0.9764, Specificity: 0.9926
# F1-Score: 0.9792, MCC: 0.9707
# Epoch 00047: reducing learning rate of group 0 to 1.0000e-06.
# ================================================================
# Train Epoch: 48 [3358/3358 (100.00%)]  Accuracy: 95.55%  Loss: 0.0068
# Test set: Accuracy: 94.59%  Loss: 0.0261
# TP: 11525924, FP: 203092, TN: 28340114, FN: 285615
# Sensitivity: 0.9758, Specificity: 0.9929
# F1-Score: 0.9792, MCC: 0.9707
# ================================================================
# Train Epoch: 49 [3358/3358 (100.00%)]  Accuracy: 95.55%  Loss: 0.0067
# Test set: Accuracy: 94.59%  Loss: 0.0260
# TP: 11533720, FP: 210101, TN: 28333105, FN: 277819
# Sensitivity: 0.9765, Specificity: 0.9926
# F1-Score: 0.9793, MCC: 0.9708
# ================================================================
# Train Epoch: 50 [3358/3358 (100.00%)]  Accuracy: 95.55%  Loss: 0.0067
# Test set: Accuracy: 94.59%  Loss: 0.0261
# TP: 11529648, FP: 206206, TN: 28337000, FN: 281891
# Sensitivity: 0.9761, Specificity: 0.9928
# F1-Score: 0.9793, MCC: 0.9707
# ================================================================

# %%
accs_np = np.array(accs)
losses_np = np.array(losses)
np.save('./nested_unet_accurate_acc.npy', accs_np)
np.save('./nested_unet_accurate_loss.npy', losses_np)

torch.save(best_acc_model, './nested_unet_accurate_best_acc_model.pt')
torch.save(best_acc_model_state, './nested_unet_accurate_best_acc_model_state.pt')
torch.save(best_f1_model, './nested_unet_accurate_best_f1_model.pt')
torch.save(best_f1_model_state, './nested_unet_accurate_best_f1_model_state.pt')
