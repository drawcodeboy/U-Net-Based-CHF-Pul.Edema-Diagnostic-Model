# %%
import torch
from torch import nn
from torchvision import transforms
from torchvision import models
from torchvision.transforms.functional import to_pil_image
import matplotlib.pyplot as plt
from monai.losses import DiceLoss
from PIL import Image
from PIL import ImageFilter
from PIL import ImageOps
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
from copy import copy
from copy import deepcopy
import cv2
import sys
import os
import pandas as pd
import numpy as np
import random
from pathlib import Path
import math
from SA_UNet import SA_UNet
# from evaluation import *

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True' # dead kernel for matplotlib

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
metadata = pd.read_csv('../doby_meta.csv')
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7064 entries, 0 to 7063
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      7064 non-null   int64
#  1   study_id        7064 non-null   int64
#  2   dicom_id        7064 non-null   object
#  3   DicomPath       7064 non-null   object
#  4   edema_severity  7064 non-null   int64
#  5   normal          7064 non-null   int64
#  6   CHF             7064 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 338.2+ KB

# %%
metadata = metadata[metadata['subject_id'] < 16000000]
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4198 entries, 0 to 4197
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      4198 non-null   int64
#  1   study_id        4198 non-null   int64
#  2   dicom_id        4198 non-null   object
#  3   DicomPath       4198 non-null   object
#  4   edema_severity  4198 non-null   int64
#  5   normal          4198 non-null   int64
#  6   CHF             4198 non-null   bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 233.7+ KB

# %%
SEG_BASE_PATH = '../chest-x-ray-dataset-with-lung-segmentation-1.0.0/chest-x-ray-dataset-with-lung-segmentation-1.0.0'
ORIG_BASE_PATH = '../physionet.org/files/mimic-cxr-jpg/2.0.0'

# %%
TRAIN_TRANSFORMS = transforms.Compose([
    transforms.ToTensor()
])

TARGET_TRANSFORMS = transforms.Compose([
    transforms.ToTensor()
])

# %%
class Dataset(Dataset):
    def __init__(self, metadata, mask_base_path, orig_base_path, transform=None, target_transform=None):
        self.metadata = metadata
        self.base_path = Path(orig_base_path)
        self.mask_path = Path(mask_base_path)
        
        self.transform = transform
        self.target_transform = target_transform
        
    def __getitem__(self, idx):
        detail_path = self.metadata.loc[idx, 'DicomPath']
        y_path = self.mask_path / Path(str(detail_path[:-4]) + '-mask.jpg')
        x_path = self.base_path / Path(str(detail_path))

        y = Image.open(str(y_path))
        x = cv2.imread(str(x_path), cv2.IMREAD_GRAYSCALE)
        x = cv2.resize(x, dsize=(224, 224), interpolation=cv2.INTER_AREA)

        del detail_path
        del y_path
        del x_path

        # 이것 때문인지는 모르겠는데 ToTensor로 Normalize가 안 된다.
        # y = np.where(y > 128, 255, 0) # 128 threshold
        # y = np.where(y > 128, 255, 0) / 255.
        
        if self.transform:
            x = self.transform(x)

        if self.target_transform:
            y = self.target_transform(y)

        return x, y

    def __len__(self):
        return self.metadata['normal'].count()

# %%
ds = Dataset(metadata, 
             SEG_BASE_PATH, 
             ORIG_BASE_PATH,
             transform=TRAIN_TRANSFORMS,
             target_transform=TARGET_TRANSFORMS)

# %%
ds_size = len(ds)
train_size = int(ds_size * 0.8)
test_size = ds_size - train_size
train_ds, test_ds = random_split(ds, [train_size, test_size], generator=torch.manual_seed(42))

# %%
train_dl = DataLoader(train_ds, batch_size=16, shuffle=True)
test_dl = DataLoader(test_ds, batch_size=8, shuffle=True)

# %%
model = SA_UNet(channel=1, block_size=10) # feature size 10%
model.to(device)
# Out:
# SA_UNet(
#   (e1): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop1): DropBlock()
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop2): DropBlock()
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (e2): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop1): DropBlock()
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop2): DropBlock()
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (e3): EncoderBlock(
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop1): DropBlock()
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop2): DropBlock()
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (sam): SpatialAttentionModule(
#     (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (sigmoid): Sigmoid()
#   )
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (d1): DecoderBlock(
#     (transposeConv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop1): DropBlock()
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop2): DropBlock()
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (d2): DecoderBlock(
#     (transposeConv): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop1): DropBlock()
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop2): DropBlock()
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (d3): DecoderBlock(
#     (transposeConv): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#     (convBlk): ConvBlock(
#       (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop1): DropBlock()
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (drop2): DropBlock()
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (convOut): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#   (sigmoid): Sigmoid()
#   (relu): ReLU()
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
schedular = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
loss_fn = DiceLoss(reduction='mean').to(device)

# %%
def train(model, data_loader, optimizer, epoch):
    model.train()
    running_loss = 0
    running_acc = 0
    n_data = 0

    for batch_idx, (batch, target) in enumerate(data_loader, start=1):
        batch, target = batch.to(device), target.to(device)

        optimizer.zero_grad()

        output = model(batch)
        output_flat = output.view(output.size(0), -1)
        target_flat = target.view(target.size(0), -1)

        loss = loss_fn(output_flat, target_flat)
        running_loss += loss.item()

        output_flat = (output_flat >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)
        correct = (output_flat == target_flat).sum().item()
        running_acc += correct

        loss.backward()
        optimizer.step()

        # Pixel 별 Accuracy
        n_data += len(batch)
        output_pixels = (output_flat.shape[1])
        
        print(f'\rTrain Epoch: {epoch} [{n_data}/{len(data_loader.dataset)} ({100 * batch_idx / len(data_loader):.2f}%)]  Accuracy: {100*running_acc/(n_data*output_pixels):.2f}%  Loss: {running_loss/batch_idx:.4f}', end='')

# %%
def test(model, data_loader):
    model.eval()
    test_acc = 0
    test_loss = 0
    n_data = 0
    TP, FP, TN, FN = 0, 0, 0, 0
    output_pixels = 0
    
    with torch.no_grad():
        for batch, target in data_loader:
            batch, target = batch.to(device), target.to(device)

            output = model(batch)

            output_flat = output.view(output.size(0), -1)
            target_flat = target.view(target.size(0), -1)

            loss = loss_fn(output_flat, target_flat)
            test_loss += loss.item()

            output_flat = (output_flat >= torch.FloatTensor([0.5]).to(device)).type(torch.float32)

            correct = (output_flat == target_flat).sum().item()
            test_acc += correct

            TP += ((output_flat == target_flat) & (target_flat == 1)).sum().item()
            FP += ((output_flat != target_flat) & (target_flat == 0)).sum().item()
            TN += ((output_flat == target_flat) & (target_flat == 0)).sum().item()
            FN += ((output_flat != target_flat) & (target_flat == 1)).sum().item()
            
            n_data += len(batch)
            output_pixels = (output_flat.shape[1])
            
            print(f'\rTest set: [{100*n_data/len(data_loader.dataset):.2f}%]', end='')
    
    test_acc = 100 * test_acc / (len(data_loader.dataset)*output_pixels)
    test_loss = test_loss / len(data_loader)
    
    print(f'\rTest set: Accuracy: {test_acc:.2f}%  Loss: {test_loss:.4f}')

    return test_acc, test_loss, TP, FP, TN, FN

# %%
def getMetric(TP, FP, TN, FN):
    # base case: divide by zero
    TP = 0.1 if TP == 0 else TP
    FP = 0.1 if FP == 0 else FP
    TN = 0.1 if TN == 0 else TN
    FN = 0.1 if FN == 0 else FN
    
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    f1_score = 2*precision*recall/(precision+recall)
    mcc = ((TP*TN)-(FP*FN))/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    
    return sensitivity, specificity, f1_score, mcc

# %%
accs = []
losses = []
best_acc = 0
best_f1 = 0

best_acc_model = None
best_acc_model_state = None
best_f1_model = None
best_f1_model_state = None

# %%
for epoch in range(1, 50+1):
    train(model, train_dl, optimizer, epoch)
    
    print()
    
    acc, loss, tp, fp, tn, fn = test(model, test_dl)
    sensitivity, specificity, f1_score, mcc = getMetric(tp, fp, tn, fn)
    print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')
    print(f'Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}\nF1-Score: {f1_score:.4f}, MCC: {mcc:.4f}')

    if acc > best_acc:
        best_acc = acc
        best_acc_model = deepcopy(model)
        best_acc_model_state = deepcopy(model.state_dict())

    if f1_score > best_f1:
        best_f1 = f1_score
        best_f1_model = deepcopy(model)
        best_f1_model_state = deepcopy(model.state_dict())
        
    schedular.step(loss)
    accs.append(acc)
    losses.append(loss)

    print('================================================================')
# Out:
# Train Epoch: 1 [3358/3358 (100.00%)]  Accuracy: 77.76%  Loss: 0.4590
# Test set: Accuracy: 88.73%  Loss: 0.3016
# TP: 11028746, FP: 2174478, TN: 26368728, FN: 782793
# Sensitivity: 0.9337, Specificity: 0.9238
# F1-Score: 0.8818, MCC: 0.8316
# ================================================================
# Train Epoch: 2 [3358/3358 (100.00%)]  Accuracy: 89.20%  Loss: 0.3517
# Test set: Accuracy: 90.78%  Loss: 0.2322
# TP: 11164295, FP: 1445834, TN: 27097372, FN: 647244
# Sensitivity: 0.9452, Specificity: 0.9493
# F1-Score: 0.9143, MCC: 0.8781
# ================================================================
# Train Epoch: 3 [3358/3358 (100.00%)]  Accuracy: 90.52%  Loss: 0.3068
# Test set: Accuracy: 91.63%  Loss: 0.2032
# TP: 11232707, FP: 1156998, TN: 27386208, FN: 578832
# Sensitivity: 0.9510, Specificity: 0.9595
# F1-Score: 0.9283, MCC: 0.8981
# ================================================================
# Train Epoch: 4 [3358/3358 (100.00%)]  Accuracy: 91.26%  Loss: 0.2697
# Test set: Accuracy: 92.17%  Loss: 0.1804
# TP: 11243900, FP: 940567, TN: 27602639, FN: 567639
# Sensitivity: 0.9519, Specificity: 0.9670
# F1-Score: 0.9371, MCC: 0.9108
# ================================================================
# Train Epoch: 5 [3358/3358 (100.00%)]  Accuracy: 91.91%  Loss: 0.2356
# Test set: Accuracy: 92.57%  Loss: 0.1526
# TP: 11375541, FP: 903526, TN: 27639680, FN: 435998
# Sensitivity: 0.9631, Specificity: 0.9683
# F1-Score: 0.9444, MCC: 0.9211
# ================================================================
# Train Epoch: 6 [3358/3358 (100.00%)]  Accuracy: 92.24%  Loss: 0.2070
# Test set: Accuracy: 92.69%  Loss: 0.1409
# TP: 11424794, FP: 900567, TN: 27642639, FN: 386745
# Sensitivity: 0.9673, Specificity: 0.9684
# F1-Score: 0.9467, MCC: 0.9244
# ================================================================
# Train Epoch: 7 [3358/3358 (100.00%)]  Accuracy: 92.55%  Loss: 0.1814
# Test set: Accuracy: 92.57%  Loss: 0.1327
# TP: 11501629, FP: 1030672, TN: 27512534, FN: 309910
# Sensitivity: 0.9738, Specificity: 0.9639
# F1-Score: 0.9449, MCC: 0.9220
# ================================================================
# Train Epoch: 8 [3358/3358 (100.00%)]  Accuracy: 92.79%  Loss: 0.1601
# Test set: Accuracy: 92.88%  Loss: 0.1108
# TP: 11486872, FP: 882890, TN: 27660316, FN: 324667
# Sensitivity: 0.9725, Specificity: 0.9691
# F1-Score: 0.9501, MCC: 0.9292
# ================================================================
# Train Epoch: 9 [3358/3358 (100.00%)]  Accuracy: 92.97%  Loss: 0.1423
# Test set: Accuracy: 93.21%  Loss: 0.0988
# TP: 11444888, FP: 701130, TN: 27842076, FN: 366651
# Sensitivity: 0.9690, Specificity: 0.9754
# F1-Score: 0.9554, MCC: 0.9368
# ================================================================
# Train Epoch: 10 [3358/3358 (100.00%)]  Accuracy: 93.09%  Loss: 0.1274
# Test set: Accuracy: 93.25%  Loss: 0.0890
# TP: 11409943, FP: 649757, TN: 27893449, FN: 401596
# Sensitivity: 0.9660, Specificity: 0.9772
# F1-Score: 0.9560, MCC: 0.9376
# ================================================================
# Train Epoch: 11 [3358/3358 (100.00%)]  Accuracy: 93.19%  Loss: 0.1144
# Test set: Accuracy: 93.37%  Loss: 0.0822
# TP: 11391302, FP: 582147, TN: 27961059, FN: 420237
# Sensitivity: 0.9644, Specificity: 0.9796
# F1-Score: 0.9579, MCC: 0.9403
# ================================================================
# Train Epoch: 12 [3358/3358 (100.00%)]  Accuracy: 93.28%  Loss: 0.1035
# Test set: Accuracy: 93.27%  Loss: 0.0747
# TP: 11488095, FP: 719964, TN: 27823242, FN: 323444
# Sensitivity: 0.9726, Specificity: 0.9748
# F1-Score: 0.9566, MCC: 0.9384
# ================================================================
# Train Epoch: 13 [3358/3358 (100.00%)]  Accuracy: 93.34%  Loss: 0.0948
# Test set: Accuracy: 93.47%  Loss: 0.0692
# TP: 11448443, FP: 596146, TN: 27947060, FN: 363096
# Sensitivity: 0.9693, Specificity: 0.9791
# F1-Score: 0.9598, MCC: 0.9430
# ================================================================
# Train Epoch: 14 [3358/3358 (100.00%)]  Accuracy: 93.45%  Loss: 0.0867
# Test set: Accuracy: 93.53%  Loss: 0.0632
# TP: 11485572, FP: 608844, TN: 27934362, FN: 325967
# Sensitivity: 0.9724, Specificity: 0.9787
# F1-Score: 0.9609, MCC: 0.9446
# ================================================================
# Train Epoch: 15 [3358/3358 (100.00%)]  Accuracy: 93.48%  Loss: 0.0812
# Test set: Accuracy: 93.55%  Loss: 0.0599
# TP: 11467975, FP: 580270, TN: 27962936, FN: 343564
# Sensitivity: 0.9709, Specificity: 0.9797
# F1-Score: 0.9613, MCC: 0.9451
# ================================================================
# Train Epoch: 16 [3358/3358 (100.00%)]  Accuracy: 93.53%  Loss: 0.0756
# Test set: Accuracy: 93.52%  Loss: 0.0603
# TP: 11466120, FP: 592698, TN: 27950508, FN: 345419
# Sensitivity: 0.9708, Specificity: 0.9792
# F1-Score: 0.9607, MCC: 0.9443
# ================================================================
# Train Epoch: 17 [3358/3358 (100.00%)]  Accuracy: 93.61%  Loss: 0.0706
# Test set: Accuracy: 93.73%  Loss: 0.0528
# TP: 11446557, FP: 484497, TN: 28058709, FN: 364982
# Sensitivity: 0.9691, Specificity: 0.9830
# F1-Score: 0.9642, MCC: 0.9493
# ================================================================
# Train Epoch: 18 [3358/3358 (100.00%)]  Accuracy: 93.62%  Loss: 0.0673
# Test set: Accuracy: 93.76%  Loss: 0.0506
# TP: 11405318, FP: 430613, TN: 28112593, FN: 406221
# Sensitivity: 0.9656, Specificity: 0.9849
# F1-Score: 0.9646, MCC: 0.9499
# ================================================================
# Train Epoch: 19 [3358/3358 (100.00%)]  Accuracy: 93.66%  Loss: 0.0640
# Test set: Accuracy: 93.67%  Loss: 0.0513
# TP: 11488816, FP: 551238, TN: 27991968, FN: 322723
# Sensitivity: 0.9727, Specificity: 0.9807
# F1-Score: 0.9634, MCC: 0.9481
# ================================================================
# Train Epoch: 20 [3358/3358 (100.00%)]  Accuracy: 93.69%  Loss: 0.0612
# Test set: Accuracy: 93.83%  Loss: 0.0479
# TP: 11443356, FP: 439785, TN: 28103421, FN: 368183
# Sensitivity: 0.9688, Specificity: 0.9846
# F1-Score: 0.9659, MCC: 0.9517
# ================================================================
# Train Epoch: 21 [3358/3358 (100.00%)]  Accuracy: 93.71%  Loss: 0.0588
# Test set: Accuracy: 93.84%  Loss: 0.0473
# TP: 11389470, FP: 382740, TN: 28160466, FN: 422069
# Sensitivity: 0.9643, Specificity: 0.9866
# F1-Score: 0.9659, MCC: 0.9518
# ================================================================
# Train Epoch: 22 [3358/3358 (100.00%)]  Accuracy: 93.75%  Loss: 0.0564
# Test set: Accuracy: 93.72%  Loss: 0.0487
# TP: 11359817, FP: 402819, TN: 28140387, FN: 451722
# Sensitivity: 0.9618, Specificity: 0.9859
# F1-Score: 0.9638, MCC: 0.9488
# ================================================================
# Train Epoch: 23 [3358/3358 (100.00%)]  Accuracy: 93.77%  Loss: 0.0546
# Test set: Accuracy: 93.71%  Loss: 0.0473
# TP: 11442182, FP: 486633, TN: 28056573, FN: 369357
# Sensitivity: 0.9687, Specificity: 0.9830
# F1-Score: 0.9639, MCC: 0.9489
# ================================================================
# Train Epoch: 24 [3358/3358 (100.00%)]  Accuracy: 93.78%  Loss: 0.0531
# Test set: Accuracy: 93.87%  Loss: 0.0441
# TP: 11368272, FP: 347664, TN: 28195542, FN: 443267
# Sensitivity: 0.9625, Specificity: 0.9878
# F1-Score: 0.9664, MCC: 0.9526
# ================================================================
# Train Epoch: 25 [3358/3358 (100.00%)]  Accuracy: 93.82%  Loss: 0.0514
# Test set: Accuracy: 93.69%  Loss: 0.0467
# TP: 11460866, FP: 513662, TN: 28029544, FN: 350673
# Sensitivity: 0.9703, Specificity: 0.9820
# F1-Score: 0.9637, MCC: 0.9485
# ================================================================
# Train Epoch: 26 [3358/3358 (100.00%)]  Accuracy: 93.85%  Loss: 0.0498
# Test set: Accuracy: 93.89%  Loss: 0.0428
# TP: 11404509, FP: 374365, TN: 28168841, FN: 407030
# Sensitivity: 0.9655, Specificity: 0.9869
# F1-Score: 0.9669, MCC: 0.9532
# ================================================================
# Train Epoch: 27 [3358/3358 (100.00%)]  Accuracy: 93.88%  Loss: 0.0484
# Test set: Accuracy: 93.88%  Loss: 0.0421
# TP: 11422475, FP: 396448, TN: 28146758, FN: 389064
# Sensitivity: 0.9671, Specificity: 0.9861
# F1-Score: 0.9668, MCC: 0.9530
# ================================================================
# Train Epoch: 28 [3358/3358 (100.00%)]  Accuracy: 93.90%  Loss: 0.0474
# Test set: Accuracy: 93.85%  Loss: 0.0429
# TP: 11369164, FP: 355959, TN: 28187247, FN: 442375
# Sensitivity: 0.9625, Specificity: 0.9875
# F1-Score: 0.9661, MCC: 0.9521
# ================================================================
# Train Epoch: 29 [3358/3358 (100.00%)]  Accuracy: 93.89%  Loss: 0.0469
# Test set: Accuracy: 93.89%  Loss: 0.0416
# TP: 11419506, FP: 391099, TN: 28152107, FN: 392033
# Sensitivity: 0.9668, Specificity: 0.9863
# F1-Score: 0.9668, MCC: 0.9531
# ================================================================
# Train Epoch: 30 [3358/3358 (100.00%)]  Accuracy: 93.89%  Loss: 0.0462
# Test set: Accuracy: 93.88%  Loss: 0.0415
# TP: 11460893, FP: 436860, TN: 28106346, FN: 350646
# Sensitivity: 0.9703, Specificity: 0.9847
# F1-Score: 0.9668, MCC: 0.9530
# ================================================================
# Train Epoch: 31 [3358/3358 (100.00%)]  Accuracy: 93.92%  Loss: 0.0450
# Test set: Accuracy: 93.91%  Loss: 0.0409
# TP: 11377295, FP: 337434, TN: 28205772, FN: 434244
# Sensitivity: 0.9632, Specificity: 0.9882
# F1-Score: 0.9672, MCC: 0.9537
# ================================================================
# Train Epoch: 32 [3358/3358 (100.00%)]  Accuracy: 93.93%  Loss: 0.0445
# Test set: Accuracy: 93.81%  Loss: 0.0421
# TP: 11366259, FP: 368477, TN: 28174729, FN: 445280
# Sensitivity: 0.9623, Specificity: 0.9871
# F1-Score: 0.9654, MCC: 0.9512
# ================================================================
# Train Epoch: 33 [3358/3358 (100.00%)]  Accuracy: 93.94%  Loss: 0.0439
# Test set: Accuracy: 93.89%  Loss: 0.0409
# TP: 11423291, FP: 395492, TN: 28147714, FN: 388248
# Sensitivity: 0.9671, Specificity: 0.9861
# F1-Score: 0.9668, MCC: 0.9531
# ================================================================
# Train Epoch: 34 [3358/3358 (100.00%)]  Accuracy: 93.97%  Loss: 0.0429
# Test set: Accuracy: 93.89%  Loss: 0.0408
# TP: 11419817, FP: 391270, TN: 28151936, FN: 391722
# Sensitivity: 0.9668, Specificity: 0.9863
# F1-Score: 0.9669, MCC: 0.9531
# ================================================================
# Train Epoch: 35 [3358/3358 (100.00%)]  Accuracy: 93.96%  Loss: 0.0428
# Test set: Accuracy: 93.90%  Loss: 0.0402
# TP: 11440681, FP: 407846, TN: 28135360, FN: 370858
# Sensitivity: 0.9686, Specificity: 0.9857
# F1-Score: 0.9671, MCC: 0.9534
# ================================================================
# Train Epoch: 36 [3358/3358 (100.00%)]  Accuracy: 93.99%  Loss: 0.0420
# Test set: Accuracy: 93.91%  Loss: 0.0402
# TP: 11394095, FP: 358094, TN: 28185112, FN: 417444
# Sensitivity: 0.9647, Specificity: 0.9875
# F1-Score: 0.9671, MCC: 0.9535
# ================================================================
# Train Epoch: 37 [3358/3358 (100.00%)]  Accuracy: 94.00%  Loss: 0.0414
# Test set: Accuracy: 93.89%  Loss: 0.0401
# TP: 11442672, FP: 414556, TN: 28128650, FN: 368867
# Sensitivity: 0.9688, Specificity: 0.9855
# F1-Score: 0.9669, MCC: 0.9532
# ================================================================
# Train Epoch: 38 [3358/3358 (100.00%)]  Accuracy: 94.01%  Loss: 0.0411
# Test set: Accuracy: 93.94%  Loss: 0.0394
# TP: 11383426, FP: 332628, TN: 28210578, FN: 428113
# Sensitivity: 0.9638, Specificity: 0.9883
# F1-Score: 0.9677, MCC: 0.9544
# ================================================================
# Train Epoch: 39 [3358/3358 (100.00%)]  Accuracy: 94.00%  Loss: 0.0410
# Test set: Accuracy: 93.97%  Loss: 0.0387
# TP: 11416832, FP: 354629, TN: 28188577, FN: 394707
# Sensitivity: 0.9666, Specificity: 0.9876
# F1-Score: 0.9682, MCC: 0.9551
# ================================================================
# Train Epoch: 40 [3358/3358 (100.00%)]  Accuracy: 94.02%  Loss: 0.0405
# Test set: Accuracy: 93.97%  Loss: 0.0389
# TP: 11370623, FP: 308708, TN: 28234498, FN: 440916
# Sensitivity: 0.9627, Specificity: 0.9892
# F1-Score: 0.9681, MCC: 0.9550
# ================================================================
# Train Epoch: 41 [3358/3358 (100.00%)]  Accuracy: 94.03%  Loss: 0.0401
# Test set: Accuracy: 93.89%  Loss: 0.0404
# TP: 11293313, FP: 263942, TN: 28279264, FN: 518226
# Sensitivity: 0.9561, Specificity: 0.9908
# F1-Score: 0.9665, MCC: 0.9530
# ================================================================
# Train Epoch: 42 [3358/3358 (100.00%)]  Accuracy: 94.06%  Loss: 0.0396
# Test set: Accuracy: 93.93%  Loss: 0.0391
# TP: 11442116, FP: 395609, TN: 28147597, FN: 369423
# Sensitivity: 0.9687, Specificity: 0.9861
# F1-Score: 0.9677, MCC: 0.9542
# ================================================================
# Train Epoch: 43 [3358/3358 (100.00%)]  Accuracy: 94.06%  Loss: 0.0394
# Test set: Accuracy: 93.98%  Loss: 0.0382
# TP: 11387827, FP: 319095, TN: 28224111, FN: 423712
# Sensitivity: 0.9641, Specificity: 0.9888
# F1-Score: 0.9684, MCC: 0.9554
# ================================================================
# Train Epoch: 44 [3358/3358 (100.00%)]  Accuracy: 94.08%  Loss: 0.0389
# Test set: Accuracy: 93.93%  Loss: 0.0393
# TP: 11449997, FP: 405169, TN: 28138037, FN: 361542
# Sensitivity: 0.9694, Specificity: 0.9858
# F1-Score: 0.9676, MCC: 0.9542
# ================================================================
# Train Epoch: 45 [3358/3358 (100.00%)]  Accuracy: 94.10%  Loss: 0.0384
# Test set: Accuracy: 93.89%  Loss: 0.0401
# TP: 11337740, FP: 309593, TN: 28233613, FN: 473799
# Sensitivity: 0.9599, Specificity: 0.9892
# F1-Score: 0.9666, MCC: 0.9530
# ================================================================
# Train Epoch: 46 [3358/3358 (100.00%)]  Accuracy: 94.08%  Loss: 0.0385
# Test set: Accuracy: 93.95%  Loss: 0.0390
# TP: 11348698, FP: 295687, TN: 28247519, FN: 462841
# Sensitivity: 0.9608, Specificity: 0.9896
# F1-Score: 0.9677, MCC: 0.9545
# ================================================================
# Train Epoch: 47 [3358/3358 (100.00%)]  Accuracy: 94.09%  Loss: 0.0383
# Test set: Accuracy: 93.95%  Loss: 0.0387
# TP: 11349871, FP: 294990, TN: 28248216, FN: 461668
# Sensitivity: 0.9609, Specificity: 0.9897
# F1-Score: 0.9677, MCC: 0.9546
# ================================================================
# Train Epoch: 48 [3358/3358 (100.00%)]  Accuracy: 94.10%  Loss: 0.0380
# Test set: Accuracy: 93.92%  Loss: 0.0394
# TP: 11407454, FP: 367142, TN: 28176064, FN: 404085
# Sensitivity: 0.9658, Specificity: 0.9871
# F1-Score: 0.9673, MCC: 0.9538
# ================================================================
# Train Epoch: 49 [3358/3358 (100.00%)]  Accuracy: 94.11%  Loss: 0.0378
# Test set: Accuracy: 93.97%  Loss: 0.0382
# TP: 11436174, FP: 375025, TN: 28168181, FN: 375365
# Sensitivity: 0.9682, Specificity: 0.9869
# F1-Score: 0.9682, MCC: 0.9551
# ================================================================
# Train Epoch: 50 [3358/3358 (100.00%)]  Accuracy: 94.11%  Loss: 0.0377
# Test set: Accuracy: 93.89%  Loss: 0.0397
# TP: 11419738, FP: 388982, TN: 28154224, FN: 391801
# Sensitivity: 0.9668, Specificity: 0.9864
# F1-Score: 0.9669, MCC: 0.9533
# ================================================================

# %%
accs_np = np.array(accs)
losses_np = np.array(losses)
np.save('./sa_unet_10_acc.npy', accs_np)
np.save('./sa_unet_10_loss.npy', losses_np)

torch.save(best_acc_model, './sa_unet_10_best_acc_model.pt')
torch.save(best_acc_model_state, './sa_unet_10_best_acc_model_state.pt')
torch.save(best_f1_model, './sa_unet_10_best_f1_model.pt')
torch.save(best_f1_model_state, './sa_unet_10_best_f1_model_state.pt')
